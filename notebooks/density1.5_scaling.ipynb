# %%
# !which python
import pandas as pd
print(pd.__version__)
import sys
print(sys.version)
import inspect
print(inspect.getfile(pd))
# Out:
# /gpfs/bbp.cscs.ch/ssd/apps/bsd/2024-02-01/stage_externals/install_gcc-12.3.0-skylake/python-3.11.6-bj4i6m/bin/python
# 2.2.1
# 3.12.2 | packaged by Anaconda, Inc. | (main, Feb 27 2024, 17:35:02) [GCC 11.2.0]
# /gpfs/bbp.cscs.ch/data/project/proj84/csaba/git/cellden/lib/python3.12/site-packages/pandas/__init__.py

# %%
import os, sys, copy
import pandas as pd
from voxcell.nexus.voxelbrain import RegionMap
import numpy as np
import pickle
import nrrd

import re
import multiprocessing as mp

sys.path.append('/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/notebooks/scripts/')

from helper_functions import get_all_filenames, get_csv_filenames, extract_prefix_from_filenames, read_and_concat_csv_files_new, combine_rows_and_calculate_average, create_combined_dataframe

# %% [markdown]
# # Start
#
# This notebook starts after data was created from MERFISH slices and stored as csv and pickle files.
# We examine scaling individual cell groups based on literature: https://www.pnas.org/doi/full/10.1073/pnas.0604911103
# - Total cells (M): 108.69 ± 16.25
# - Total neurons (M): 70.89 ± 10.41
# - CCTX: 17.8 ± 3.4% of neurons (this is not the isocortex)
# - CRB: 59.0 ± 5.0% of neurons
#
#     - "Cerebral cortex" 688 = "Cortical plate" 695 + "Cortical subplate" 703
#         - "Cerebral nuclei is not part of the cer.ctx)
#         - Cerebral cortex is not the Cerebellar cortex (the Cerebellar cortex is part of the Cerebellum)
#
# Note, that we cannot scale glia because we don't have information on that. only all non-neuron types number is known.
#
# From test_tutorial_cerebellum.ipynb we decided to only scale exc cells (ie granular layer) in the CRB.

# %%
total_cells = 108.69 * 1_000_000
total_neurons = 70.89 * 1_000_000
total_ctx = total_neurons * 17.8 / 100 #17.8% of the total neurons
total_crb = total_neurons * 59.0 / 100 #59% of the total neurons
total_rest = total_neurons * ( 100 - 59.0 -17.8 )/ 100
total_nonneuron = total_cells - total_neurons
print("Neurons only: ")
print("CTX: " '{:,.0f}'.format(total_ctx,), 
      "CRB: " '{:,.0f}'.format(total_crb),
      "REST: " '{:,.0f}'.format(total_rest),
      "Non-NEURON: " '{:,.0f}'.format(total_nonneuron))
# Out:
# Neurons only:
# CTX: 12,618,420 CRB: 41,825,100 REST: 16,446,480 Non-NEURON: 37,800,000

# %%
## Where did these come from: density1.2_print_info.ipynb using unscaled numbers (if you created the pickle file)
## density1.3_print_info_unscaled.ipynb

#New (See ipynb for up-to-date estimation)
'''
#CCFv3a: annotation_25_2022_CCFv3a.nrrd
The brain area wholebrain has 5272 different cell types
Total sum of cells: 92,231,205
The brain area Cerebral cortex has 3095 different cell types
Total sum of cells: 43,858,738
The brain area isocortex has 946 different cell types
Total sum of cells: 28,535,494
The brain area cerebellum has 861 different cell types
Total sum of cells: 6,224,671

The brain area wholebrain has 5155 different neuron types
Total sum of these cells: 52,040,591
The brain area Cerebral cortex has 2989 different neuron types
Total sum of these cells: 29,125,071
The brain area isocortex has 870 different neuron types
Total sum of these cells: 19,101,627
The brain area cerebellum has 781 different neuron types
Total sum of these cells: 3,543,172

The brain area wholebrain has 117/117 different nonneuron types
Total sum of these cells: 40,190,614
The brain area Cerebral cortex has 106/117 different nonneuron types
Total sum of these cells: 14,733,667
The brain area isocortex has 76/117 different nonneuron types
Total sum of these cells: 9,433,867
The brain area cerebellum has 80/117 different nonneuron types
Total sum of these cells: 2,681,499
The brain area fiber_tracts_ids has 114/117 different nonneuron types
Total sum of these cells: 7,881,000
'''

#Cerebral cortex, cerebellum, REST
mfish_ctx = 29_125_071
mfish_crb = 3_543_172
mfish_rest = 52_040_591 - mfish_ctx - mfish_crb
mfish_nonneuron = 40_190_614

# %%
#Scaling factors (overview only)
1/(mfish_ctx/total_ctx)*100, 1/(mfish_crb/total_crb)*100, 1/(mfish_rest/total_rest)*100, 1/(mfish_nonneuron/total_nonneuron)*100
# Out:
# (43.3249415941338, 1180.4422703724235, 84.89667850278138, 94.05181020623372)

# %%
# %%time

#Load metadata of cell type information. Using classes we can easily group all 5k+ ctypes into larger groups
meta_path = "/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/metadata/WMB-10X/20231215/views/cell_metadata_with_cluster_annotation.csv"
columns_to_read = ['class', 'subclass', 'cluster']
#metadata = pd.read_csv(meta_path, dtype={'cell_label':str}, low_memory=False)
metadata = pd.read_csv(meta_path, usecols=columns_to_read, )

n_classes = ['01 IT-ET Glut', '02 NP-CT-L6b Glut', '03 OB-CR Glut',
       '04 DG-IMN Glut', '05 OB-IMN GABA', '06 CTX-CGE GABA',
       '07 CTX-MGE GABA', '08 CNU-MGE GABA', '09 CNU-LGE GABA',
       '10 LSX GABA', '11 CNU-HYa GABA', '12 HY GABA', '13 CNU-HYa Glut',
       '14 HY Glut', '15 HY Gnrh1 Glut', '16 HY MM Glut', '17 MH-LH Glut',
       '18 TH Glut', '19 MB Glut', '20 MB GABA', '21 MB Dopa',
       '22 MB-HB Sero', '23 P Glut', '24 MY Glut', '25 Pineal Glut',
       '26 P GABA', '27 MY GABA', '28 CB GABA', '29 CB Glut',]

nn_classes = ['30 Astro-Epen', '31 OPC-Oligo', '32 OEC', '33 Vascular',
       '34 Immune']

exc = ['01 IT-ET Glut', '02 NP-CT-L6b Glut', '03 OB-CR Glut',
      '04 DG-IMN Glut', '13 CNU-HYa Glut', '14 HY Glut', '15 HY Gnrh1 Glut', '16 HY MM Glut', '17 MH-LH Glut',
      '18 TH Glut', '19 MB Glut', '23 P Glut', '24 MY Glut', '25 Pineal Glut', '29 CB Glut',]
inh = ['05 OB-IMN GABA', '06 CTX-CGE GABA', '07 CTX-MGE GABA', '08 CNU-MGE GABA', '09 CNU-LGE GABA',
      '10 LSX GABA', '11 CNU-HYa GABA', '12 HY GABA', '20 MB GABA', '26 P GABA', '27 MY GABA', '28 CB GABA', ]
other = ['21 MB Dopa', '22 MB-HB Sero', ]
exci_inhib_su = exc + inh

astrotypes = ['5206 Bergmann NN_1', '5207 Astro-CB NN_1', '5208 Astro-NT NN_1',
       '5209 Astro-NT NN_1', '5210 Astro-NT NN_1', '5211 Astro-NT NN_1',
       '5212 Astro-NT NN_1', '5213 Astro-NT NN_1', '5214 Astro-NT NN_2',
       '5215 Astro-NT NN_2', '5216 Astro-NT NN_2', '5217 Astro-NT NN_2',
       '5218 Astro-TE NN_1', '5219 Astro-TE NN_1', '5220 Astro-TE NN_1',
       '5221 Astro-TE NN_1', '5222 Astro-TE NN_2', '5223 Astro-TE NN_2',
       '5224 Astro-TE NN_3', '5225 Astro-TE NN_3', '5226 Astro-TE NN_3',
       '5227 Astro-TE NN_3', '5228 Astro-TE NN_4', '5229 Astro-TE NN_5',
       '5230 Astro-TE NN_5', '5231 Astro-OLF NN_1', '5232 Astro-OLF NN_1',
       '5233 Astro-OLF NN_2', '5234 Astro-OLF NN_2',
       '5235 Astro-OLF NN_3', '5236 Astro-OLF NN_3',]

microglia = ['5312 Microglia NN_1']

oligos = ['5266 OPC NN_1', '5267 OPC NN_1',
       '5268 OPC NN_1', '5269 OPC NN_1', '5270 OPC NN_1', '5271 OPC NN_2',
       '5272 COP NN_1', '5273 COP NN_1', '5274 COP NN_1', '5275 COP NN_1',
       '5276 COP NN_1', '5277 COP NN_1', '5278 NFOL NN_2',
       '5279 NFOL NN_2', '5280 NFOL NN_2', '5281 NFOL NN_2',
       '5282 MFOL NN_3', '5283 MFOL NN_3', '5284 MOL NN_4',
       '5285 MOL NN_4', '5286 MOL NN_4', '5287 MOL NN_4', '5288 MOL NN_4',]

glia = astrotypes + microglia + oligos

neurontypes = np.unique(metadata[metadata['class'].isin(n_classes)]['cluster'].values)
nonneurontypes = np.unique(metadata[metadata['class'].isin(nn_classes)]['cluster'].values)
exctypes = np.unique(metadata[metadata['class'].isin(exc)]['cluster'].values)
inhtypes = np.unique(metadata[metadata['class'].isin(inh)]['cluster'].values)
othertypes = np.unique(metadata[metadata['class'].isin(other)]['cluster'].values)
exci_inhib_sum = np.unique(metadata[metadata['class'].isin(exci_inhib_su)]['cluster'].values)
celltypes = np.unique(metadata['cluster'].values)
# Out:
# CPU times: user 16.3 s, sys: 455 ms, total: 16.8 s
# Wall time: 16.8 s

# %% [markdown]
# ## Load estimated densities from (density1 step) + external data (parcellation meta extended, hierarchy file)

# %%
# %%time 

download_base = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/'
root_folder = f"{download_base}results/density_calculations/"

# Get all regional density data
folder_path = f"{root_folder}csv/"
filenames = get_all_filenames(folder_path)
csv_filenames = get_csv_filenames(folder_path)
prefixes = extract_prefix_from_filenames(csv_filenames)
unique_prefixes = sorted(list(set(prefixes)))

#Create a dict of df, each containing a cell type's occurence in all regions and its densities in all regions
result_dataframes = read_and_concat_csv_files_new(csv_filenames, unique_prefixes, folder_path)
combined_result_dataframes = combine_rows_and_calculate_average(result_dataframes)
#shuffled_combined_dataframes = create_combined_dataframe(combined_result_dataframes)

file = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/metadata/parcellation_to_parcellation_term_membership_extend.csv'
parcellation_annotation = pd.read_csv(file)

#hierarchy_json = '/gpfs/bbp.cscs.ch/home/veraszto/bbp_prod_files/1.json'
hierarchy_json = '/gpfs/bbp.cscs.ch/data/project/proj84/atlas_pipeline_runs/2024-05-15T22:44:26+02:00/hierarchy_ccfv3_l23split_barrelsplit.json'
# Out:
# CPU times: user 1.32 s, sys: 124 ms, total: 1.44 s
# Wall time: 5.46 s

# %%
# Check if 'UVU' exists
if 'UVU' not in combined_result_dataframes:
    print("Non-leaf regions of the Cerebellum were removed")
else:
    print("'UVU' key exists in combined_result_dataframes")
# Out:
# Non-leaf regions of the Cerebellum were removed

# %% [markdown]
# You can combine and save the unscaled csv files (dict of dfs) into a pickle file

# %%
#write PICKLE file with densities
folder = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/'
# Assuming 'total_cells' is your dictionary of DataFrames
with open(f'{folder}non_scaled_densities_new.pickle', 'wb') as f:
    pickle.dump(combined_result_dataframes, f)

print(f"Pickle file saved here: {folder}")
# Out:
# Pickle file saved here: /gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/

# %% [markdown]
# Select a whole region (e.g. CBX, CTX, HPF) of csv files / regions in the hierarchy

# %%
region_map = RegionMap.load_json(hierarchy_json)

cerebellum = region_map.find(
        "Cerebellum", attr="name", with_descendants=True
    ) | region_map.find("arbor vitae", attr="name", with_descendants=True)
# isocortex = (
#     region_map.find("Isocortex", attr="name", with_descendants=True)
#     | region_map.find("Entorhinal area", attr="name", with_descendants=True)
#     | region_map.find("Piriform area", attr="name", with_descendants=True)
# )
cerebral_cortex = (
    region_map.find("Cerebral cortex", attr="name", with_descendants=True)
)

# %%
#This cell checks parcellation information and sees if all leaf region ids match with something in the parcellation database
ctx_leaves = []
for leaf in cerebral_cortex:
    pacellations_sets = parcellation_annotation[parcellation_annotation['label_numbers'] == leaf]
    parcallation = pacellations_sets[pacellations_sets['parcellation_term_set_name'] == 'substructure']
    if parcallation.shape[0] == 1:
        ctx_leaves.append(parcallation['cluster_as_filename'].iloc[0])
    else:
        print(str(leaf) + " " + region_map.get(leaf, "name", with_ascendants=False) +  " has seemingly no coverage.")
# Out:
# 3562104832 Primary somatosensory area, trunk, layer 2 has seemingly no coverage.
# 3215542274 Primary somatosensory area, barrel field, B4 barrel layer 6b has seemingly no coverage.
# 1945434117 Primary somatosensory area, barrel field, C1 barrel layer 6a has seemingly no coverage.
# 1643593739 Primary somatosensory area, barrel field, E5 barrel layer 2/3 has seemingly no coverage.
# 2546495501 Somatomotor areas, layer 2 has seemingly no coverage.
# 1720700944 Rostrolateral lateral visual area, layer 2 has seemingly no coverage.
# 16 Layer 6b, isocortex has seemingly no coverage.
# 2208057363 Primary somatosensory area, unassigned, layer 3 has seemingly no coverage.
# 2078623765 Infralimbic area, layer 3 has seemingly no coverage.
# 22 Posterior parietal association areas has seemingly no coverage.
# 3581771805 Primary somatosensory area, barrel field, C3 barrel layer 3 has seemingly no coverage.
# 31 Anterior cingulate area has seemingly no coverage.
# 1896413216 Laterolateral anterior visual area, layer 3 has seemingly no coverage.
# 1714311201 Primary somatosensory area, barrel field, C2 barrel layer 3 has seemingly no coverage.
# 2646114338 Frontal pole, layer 2 has seemingly no coverage.
# 39 Anterior cingulate area, dorsal part has seemingly no coverage.
# 1901850664 Primary somatosensory area, barrel field, Delta barrel layer 6b has seemingly no coverage.
# 2157537321 Primary somatosensory area, barrel field, C2 barrel layer 2/3 has seemingly no coverage.
# 1781030954 Primary somatosensory area, barrel field, D3 barrel layer 1 has seemingly no coverage.
# 44 Infralimbic area has seemingly no coverage.
# 3724099631 Primary somatosensory area, barrel field, D1 barrel layer 1 has seemingly no coverage.
# 3872485424 Primary somatosensory area, barrel field, D2 barrel layer 6b has seemingly no coverage.
# 48 Anterior cingulate area, ventral part has seemingly no coverage.
# 1104248884 Primary somatosensory area, barrel field, E2 barrel layer 4 has seemingly no coverage.
# 60 Entorhinal area, lateral part, layer 6b has seemingly no coverage.
# 1096265790 Primary somatosensory area, barrel field, D4 barrel layer 6b has seemingly no coverage.
# 1536696383 Primary somatosensory area, barrel field, E2 barrel layer 6a has seemingly no coverage.
# 1706307657 Primary somatosensory area, barrel field, C5 barrel layer 6a has seemingly no coverage.
# 3325173834 Primary somatosensory area, barrel field, E4 barrel layer 2 has seemingly no coverage.
# 3902978127 Primary somatosensory area, barrel field, A1 barrel layer 6b has seemingly no coverage.
# 1624848466 Primary somatosensory area, nose, layer 3 has seemingly no coverage.
# 2341154899 Mediomedial posterior visual area, layer 2 has seemingly no coverage.
# 1326886999 Primary somatosensory area, barrel field, D5 barrel layer 1 has seemingly no coverage.
# 2414821463 Agranular insular area, posterior part, layer 3 has seemingly no coverage.
# 3263488087 Hippocampal formation: Other has seemingly no coverage.
# 92 Entorhinal area, lateral part, layer 4 has seemingly no coverage.
# 2525505631 Primary somatosensory area, barrel field, C2 barrel layer 2 has seemingly no coverage.
# 95 Agranular insular area has seemingly no coverage.
# 104 Agranular insular area, dorsal part has seemingly no coverage.
# 107 Somatomotor areas, layer 1 has seemingly no coverage.
# 1970686062 Primary somatosensory area, barrel field, B4 barrel layer 4 has seemingly no coverage.
# 111 Agranular insular area, posterior part has seemingly no coverage.
# 1953921139 Dorsal peduncular area: Other has seemingly no coverage.
# 1453537399 Primary somatosensory area, barrel field, D4 barrel layer 2/3 has seemingly no coverage.
# 3724992631 Visual areas, layer 2 has seemingly no coverage.
# 3080022137 Primary somatosensory area, barrel field, B3 barrel layer 3 has seemingly no coverage.
# 3495145594 Primary somatosensory area, barrel field, B1 barrel layer 4 has seemingly no coverage.
# 119 Agranular insular area, ventral part has seemingly no coverage.
# 1477785742 Primary somatosensory area, barrel field, E1 barrel layer 4 has seemingly no coverage.
# 2167613582 Ventral auditory area, layer 3 has seemingly no coverage.
# 151 Accessory olfactory bulb has seemingly no coverage.
# 152 Piriform area, layers 1-3 has seemingly no coverage.
# 1203939479 Piriform-amygdalar area: Other has seemingly no coverage.
# 1869881498 Primary somatosensory area, barrel field, C5 barrel layer 6b has seemingly no coverage.
# 3376791707 Agranular insular area, ventral part, layer 3 has seemingly no coverage.
# 160 Anterior olfactory nucleus, layer 1 has seemingly no coverage.
# 2097438884 Primary somatosensory area, barrel field, E6 barrel layer 5 has seemingly no coverage.
# 167 Anterior olfactory nucleus, dorsal part has seemingly no coverage.
# 3841505448 Primary somatosensory area, barrel field, E4 barrel layer 1 has seemingly no coverage.
# 168 Anterior olfactory nucleus, layer 2 has seemingly no coverage.
# 3277826222 Primary somatosensory area, barrel field, D8 barrel layer 6a has seemingly no coverage.
# 3618095278 Primary somatosensory area, barrel field, E7 barrel has seemingly no coverage.
# 3693772975 Primary somatosensory area, upper limb, layer 2 has seemingly no coverage.
# 3880005807 Orbital area, layer 3 has seemingly no coverage.
# 175 Anterior olfactory nucleus, external part has seemingly no coverage.
# 179 Anterior cingulate area, layer 6a has seemingly no coverage.
# 183 Anterior olfactory nucleus, lateral part has seemingly no coverage.
# 184 Frontal pole, cerebral cortex has seemingly no coverage.
# 1644849336 Primary somatosensory area, barrel field, B1 barrel layer 5 has seemingly no coverage.
# 3577346235 Primary somatosensory area, barrel field, A1 barrel layer 6a has seemingly no coverage.
# 3379749055 Primary somatosensory area, barrel field, A3 barrel layer 6b has seemingly no coverage.
# 3920533696 Postrhinal area, layer 3 has seemingly no coverage.
# 191 Anterior olfactory nucleus, medial part has seemingly no coverage.
# 192 Cortical amygdalar area, anterior part, layer 1 has seemingly no coverage.
# 195 Prelimbic area, layer 2 has seemingly no coverage.
# 1261138116 Primary somatosensory area, barrel field, C6 barrel has seemingly no coverage.
# 2810081477 Primary somatosensory area, barrel field, Gamma barrel layer 1 has seemingly no coverage.
# 1897015494 Primary somatosensory area, barrel field, E3 barrel layer 1 has seemingly no coverage.
# 199 Anterior olfactory nucleus, posteroventral part has seemingly no coverage.
# 3565367498 Primary somatosensory area, barrel field, B3 barrel layer 1 has seemingly no coverage.
# 200 Cortical amygdalar area, anterior part, layer 2 has seemingly no coverage.
# 208 Cortical amygdalar area, anterior part, layer 3 has seemingly no coverage.
# 216 Cortical amygdalar area, posterior part, lateral zone, layer 1 has seemingly no coverage.
# 2657138906 Primary somatosensory area, barrel field, B3 barrel layer 2/3 has seemingly no coverage.
# 219 Somatomotor areas, layer 2/3 has seemingly no coverage.
# 2658097375 Primary somatosensory area, barrel field, E3 barrel layer 4 has seemingly no coverage.
# 224 Cortical amygdalar area, posterior part, lateral zone, layer 2 has seemingly no coverage.
# 227 Anterior cingulate area, layer 6b has seemingly no coverage.
# 2644357350 Primary somatosensory area, barrel field, E8 barrel layer 6b has seemingly no coverage.
# 232 Cortical amygdalar area, posterior part, lateral zone, layer 3 has seemingly no coverage.
# 1848522986 Primary somatosensory area, barrel field, Gamma barrel layer 6b has seemingly no coverage.
# 1433026796 Primary somatosensory area, barrel field, E2 barrel layer 3 has seemingly no coverage.
# 240 Cortical amygdalar area, posterior part, medial zone, layer 1 has seemingly no coverage.
# 241 Posterior parietal association areas, layer 2/3 has seemingly no coverage.
# 1037502706 Anterior cingulate area, layer 3 has seemingly no coverage.
# 1758306548 Primary motor area, layer 3 has seemingly no coverage.
# 247 Auditory areas has seemingly no coverage.
# 3219108088 Primary somatosensory area, barrel field, C1 barrel layer 4 has seemingly no coverage.
# 248 Cortical amygdalar area, posterior part, medial zone, layer 2 has seemingly no coverage.
# 2790136061 Primary somatosensory area, barrel field, Gamma barrel layer 2 has seemingly no coverage.
# 254 Retrosplenial area has seemingly no coverage.
# 256 Cortical amygdalar area, posterior part, medial zone, layer 3 has seemingly no coverage.
# 1558550786 Primary somatosensory area, barrel field, C1 barrel layer 2 has seemingly no coverage.
# 259 Entorhinal area, medial part, ventral zone, layer 1 has seemingly no coverage.
# 264 Orbital area, layer 1 has seemingly no coverage.
# 267 Dorsal peduncular area, layer 6a has seemingly no coverage.
# 1117257996 Primary somatosensory area, barrel field, D4 barrel layer 1 has seemingly no coverage.
# 1275601165 Primary somatosensory area, barrel field, Delta barrel layer 2 has seemingly no coverage.
# 2936441103 Primary somatosensory area, barrel field, B4 barrel layer 6a has seemingly no coverage.
# 1210837267 Primary somatosensory area, barrel field, A2 barrel layer 6a has seemingly no coverage.
# 276 Piriform area, molecular layer has seemingly no coverage.
# 284 Piriform area, pyramidal layer has seemingly no coverage.
# 1691306271 Primary somatosensory area, barrel field, Delta barrel layer 1 has seemingly no coverage.
# 3620340000 Primary somatosensory area, barrel field, E6 barrel layer 2/3 has seemingly no coverage.
# 1393608993 Primary somatosensory area, barrel field, D7 barrel layer 3 has seemingly no coverage.
# 1315950883 Primary somatosensory area, barrel field, D6 barrel layer 1 has seemingly no coverage.
# 3486673188 Primary somatosensory area, barrel field, Beta barrel layer 1 has seemingly no coverage.
# 3956191525 Retrosplenial area, dorsal part, layer 3 has seemingly no coverage.
# 3347675430 Primary somatosensory area, barrel field, B4 barrel has seemingly no coverage.
# 291 Piriform area, polymorph layer has seemingly no coverage.
# 297 Taenia tecta, dorsal part, layers 1-4 has seemingly no coverage.
# 299 Somatomotor areas, layer 5 has seemingly no coverage.
# 295 Basolateral amygdalar nucleus has seemingly no coverage.
# 2892558637 Retrosplenial area, lateral agranular part, layer 3 has seemingly no coverage.
# 3301183793 Primary somatosensory area, barrel field, D6 barrel layer 3 has seemingly no coverage.
# 1099096371 Primary somatosensory area, barrel field, D3 barrel layer 6b has seemingly no coverage.
# 3796365620 Primary somatosensory area, barrel field, C6 barrel layer 6a has seemingly no coverage.
# 3835740469 Primary somatosensory area, barrel field, C3 barrel layer 1 has seemingly no coverage.
# 308 Posterior parietal association areas, layer 6a has seemingly no coverage.
# 306 Taenia tecta, ventral part, layers 1-3 has seemingly no coverage.
# 312 Entorhinal area, lateral part, layer 4/5 has seemingly no coverage.
# 1965375801 Primary somatosensory area, barrel field, E6 barrel has seemingly no coverage.
# 1547817274 Primary somatosensory area, barrel field, B3 barrel layer 4 has seemingly no coverage.
# 315 Isocortex has seemingly no coverage.
# 2047390011 Primary somatosensory area, barrel field, D2 barrel layer 4 has seemingly no coverage.
# 3781663036 Dorsal auditory area, layer 2 has seemingly no coverage.
# 1518704958 Primary somatosensory area, barrel field, E8 barrel layer 3 has seemingly no coverage.
# 1942628671 Ventral auditory area, layer 2 has seemingly no coverage.
# 322 Primary somatosensory area has seemingly no coverage.
# 2700046659 Primary somatosensory area, barrel field, C4 barrel layer 6b has seemingly no coverage.
# 324 Entorhinal area, medial part, ventral zone, layer 2 has seemingly no coverage.
# 319 Basomedial amygdalar nucleus has seemingly no coverage.
# 329 Primary somatosensory area, barrel field has seemingly no coverage.
# 1035739465 Primary somatosensory area, barrel field, C5 barrel layer 2 has seemingly no coverage.
# 1501393228 Primary somatosensory area, barrel field, D3 barrel layer 4 has seemingly no coverage.
# 2842134861 Primary somatosensory area, barrel field, E7 barrel layer 4 has seemingly no coverage.
# 337 Primary somatosensory area, lower limb has seemingly no coverage.
# 3990698322 Primary somatosensory area, barrel field, D6 barrel layer 2 has seemingly no coverage.
# 340 Posterior parietal association areas, layer 6b has seemingly no coverage.
# 345 Primary somatosensory area, mouth has seemingly no coverage.
# 346 Primary somatosensory area, layer 2/3 has seemingly no coverage.
# 2361776473 Retrosplenial area, dorsal part, layer 2 has seemingly no coverage.
# 352 Orbital area, layer 5 has seemingly no coverage.
# 353 Primary somatosensory area, nose has seemingly no coverage.
# 1860102496 Taenia tecta, ventral part: Other has seemingly no coverage.
# 3638507875 Primary somatosensory area, barrel field, D1 barrel layer 6b has seemingly no coverage.
# 360 Dorsal peduncular area, layer 2/3 has seemingly no coverage.
# 2598818153 Primary somatosensory area, barrel field, layer 3 has seemingly no coverage.
# 361 Primary somatosensory area, trunk has seemingly no coverage.
# 1094902124 Primary somatosensory area, barrel field, E8 barrel layer 1 has seemingly no coverage.
# 2224619882 Agranular insular area, ventral part, layer 2 has seemingly no coverage.
# 1516851569 Primary somatosensory area, barrel field, B1 barrel layer 1 has seemingly no coverage.
# 369 Primary somatosensory area, upper limb has seemingly no coverage.
# 371 Entorhinal area, medial part, ventral zone, layer 3 has seemingly no coverage.
# 1038004598 Primary somatosensory area, barrel field, D5 barrel layer 5 has seemingly no coverage.
# 375 Ammon's horn has seemingly no coverage.
# 376 Cortical amygdalar area, posterior part, lateral zone, layers 1-3 has seemingly no coverage.
# 2153924985 Posterolateral visual area, layer 2 has seemingly no coverage.
# 378 Supplemental somatosensory area has seemingly no coverage.
# 1315119484 Primary somatosensory area, barrel field, A1 barrel layer 4 has seemingly no coverage.
# 1994494334 Primary somatosensory area, barrel field, A3 barrel layer 1 has seemingly no coverage.
# 383 Cortical amygdalar area, posterior part, medial zone, layers 1-3 has seemingly no coverage.
# 3312222592 Primary somatosensory area, barrel field, E8 barrel layer 2 has seemingly no coverage.
# 3412423041 Secondary motor area, layer 2 has seemingly no coverage.
# 385 Primary visual area has seemingly no coverage.
# 387 Entorhinal area, lateral part, layer 5/6 has seemingly no coverage.
# 392 Nucleus of the lateral olfactory tract, layers 1-3 has seemingly no coverage.
# 394 Anteromedial visual area has seemingly no coverage.
# 3379356047 Primary somatosensory area, barrel field, A1 barrel layer 3 has seemingly no coverage.
# 2978179471 Primary somatosensory area, barrel field, D7 barrel layer 4 has seemingly no coverage.
# 402 Anterolateral visual area has seemingly no coverage.
# 3623254419 Primary somatosensory area, barrel field, D2 barrel layer 2 has seemingly no coverage.
# 400 Piriform-amygdalar area, layers 1-3 has seemingly no coverage.
# 2123772309 Primary somatosensory area, barrel field, E7 barrel layer 6a has seemingly no coverage.
# 408 Piriform-amygdalar area, molecular layer has seemingly no coverage.
# 409 Lateral visual area has seemingly no coverage.
# 2641148319 Primary somatosensory area, barrel field, E4 barrel layer 6b has seemingly no coverage.
# 2478012832 Primary somatosensory area, barrel field, B3 barrel layer 6a has seemingly no coverage.
# 417 Rostrolateral visual area has seemingly no coverage.
# 416 Piriform-amygdalar area, pyramidal layer has seemingly no coverage.
# 419 Entorhinal area, medial part, ventral zone, layer 4 has seemingly no coverage.
# 423 Field CA2 has seemingly no coverage.
# 424 Piriform-amygdalar area, polymorph layer has seemingly no coverage.
# 425 Posterolateral visual area has seemingly no coverage.
# 2091848107 Primary somatosensory area, barrel field, E6 barrel layer 3 has seemingly no coverage.
# 2004775342 Primary somatosensory area, barrel field, Delta barrel layer 4 has seemingly no coverage.
# 2868822451 Primary somatosensory area, barrel field, E6 barrel layer 6a has seemingly no coverage.
# 2930307508 Primary somatosensory area, barrel field, C2 barrel layer 4 has seemingly no coverage.
# 3389528505 Taenia tecta, dorsal part: Other has seemingly no coverage.
# 1881029055 Primary somatosensory area, barrel field, B3 barrel layer 2 has seemingly no coverage.
# 453 Somatosensory areas has seemingly no coverage.
# 2006047173 Primary somatosensory area, barrel field, B4 barrel layer 1 has seemingly no coverage.
# 1612593605 Primary somatosensory area, barrel field, E8 barrel layer 5 has seemingly no coverage.
# 457 Visual areas, layer 6a has seemingly no coverage.
# 1672280517 Agranular insular area, posterior part, layer 2 has seemingly no coverage.
# 3114287561 Medial visual area, layer 2 has seemingly no coverage.
# 10693 Parasubiculum, layer 1 has seemingly no coverage.
# 10694 Parasubiculum, layer 2 has seemingly no coverage.
# 10695 Parasubiculum, layer 3 has seemingly no coverage.
# 10696 Postsubiculum, layer 1 has seemingly no coverage.
# 10697 Postsubiculum, layer 2 has seemingly no coverage.
# 3896406483 Primary somatosensory area, barrel field, Alpha barrel has seemingly no coverage.
# 2525641171 Primary somatosensory area, barrel field, B1 barrel has seemingly no coverage.
# 1420546517 Primary somatosensory area, barrel field, C1 barrel layer 5 has seemingly no coverage.
# 10702 Dentate gyrus, subgranular zone has seemingly no coverage.
# 3714509274 Rostrolateral visual area, layer 3 has seemingly no coverage.
# 468 Entorhinal area, medial part, dorsal zone, layer 2a has seemingly no coverage.
# 476 Orbital area, layer 6a has seemingly no coverage.
# 2371017187 Primary somatosensory area, barrel field, C6 barrel layer 4 has seemingly no coverage.
# 2536061413 Frontal pole, layer 3 has seemingly no coverage.
# 2798287336 Primary somatosensory area, barrel field, D2 barrel layer 5 has seemingly no coverage.
# 2013207018 Primary somatosensory area, barrel field, C6 barrel layer 2/3 has seemingly no coverage.
# 1156116970 Primary somatosensory area, barrel field, D8 barrel layer 2 has seemingly no coverage.
# 2186168811 Dorsal auditory area, layer 3 has seemingly no coverage.
# 1307372013 Posterior auditory area, layer 2 has seemingly no coverage.
# 492 Orbital area, layer 2/3 has seemingly no coverage.
# 496 Dorsal peduncular area, layer 1 has seemingly no coverage.
# 497 Visual areas, layer 6b has seemingly no coverage.
# 500 Somatomotor areas has seemingly no coverage.
# 2302833148 Primary somatosensory area, barrel field, Gamma barrel layer 4 has seemingly no coverage.
# 508 Entorhinal area, medial part, dorsal zone, layer 2b has seemingly no coverage.
# 2036081150 Primary somatosensory area, barrel field, D3 barrel has seemingly no coverage.
# 2430059008 Visual areas, layer 3 has seemingly no coverage.
# 509 Subiculum, dorsal part has seemingly no coverage.
# 516 Orbital area, layer 6b has seemingly no coverage.
# 517 Postpiriform transition area, layers 1-3 has seemingly no coverage.
# 518 Subiculum, ventral part has seemingly no coverage.
# 2985091592 Laterointermediate area, layer 3 has seemingly no coverage.
# 524 Orbital area, medial part, layer 2 has seemingly no coverage.
# 1355885073 Somatosensory areas, layer 2 has seemingly no coverage.
# 2387503636 Primary somatosensory area, barrel field, D6 barrel layer 5 has seemingly no coverage.
# 533 posteromedial visual area has seemingly no coverage.
# 532 Posterior parietal association areas, layer 1 has seemingly no coverage.
# 535 Dorsal peduncular area, layer 2 has seemingly no coverage.
# 3324056088 Primary somatosensory area, barrel field, A2 barrel layer 2 has seemingly no coverage.
# 541 Temporal association areas has seemingly no coverage.
# 3202423327 Primary somatosensory area, barrel field, D4 barrel has seemingly no coverage.
# 2218254883 Ectorhinal area, layer 2 has seemingly no coverage.
# 550 Entorhinal area, medial part, dorsal zone, layer 5/6 has seemingly no coverage.
# 2887815719 Medial visual area, layer 3 has seemingly no coverage.
# 1805611561 Primary somatosensory area, barrel field, C6 barrel layer 2 has seemingly no coverage.
# 1695203883 Anterior area, layer 2 has seemingly no coverage.
# 3099716140 Primary somatosensory area, layer 3 has seemingly no coverage.
# 561 Visual areas, layer 2/3 has seemingly no coverage.
# 1668688439 Piriform area: Other has seemingly no coverage.
# 572 Anterior cingulate area, layer 1 has seemingly no coverage.
# 10698 Postsubiculum, layer 3 has seemingly no coverage.
# 3761146439 Primary somatosensory area, barrel field, A3 barrel layer 3 has seemingly no coverage.
# 584 Cortical amygdalar area, posterior part, lateral zone, layers 1-2 has seemingly no coverage.
# 10699 Presubiculum, layer 1 has seemingly no coverage.
# 2194674250 Primary somatosensory area, barrel field, B1 barrel layer 6b has seemingly no coverage.
# 10700 Presubiculum, layer 2 has seemingly no coverage.
# 589 Taenia tecta has seemingly no coverage.
# 592 Cortical amygdalar area, posterior part, medial zone, layers 1-2 has seemingly no coverage.
# 10701 Presubiculum, layer 3 has seemingly no coverage.
# 3926962776 Primary somatosensory area, barrel field, Alpha barrel layer 3 has seemingly no coverage.
# 2833279579 Primary somatosensory area, barrel field, D1 barrel layer 2/3 has seemingly no coverage.
# 606 Retrosplenial area, ventral part, layer 2 has seemingly no coverage.
# 2987319910 Primary somatosensory area, barrel field, D2 barrel layer 6a has seemingly no coverage.
# 1580329576 Presubiculum: Other has seemingly no coverage.
# 619 Nucleus of the lateral olfactory tract has seemingly no coverage.
# 3093795446 Primary somatosensory area, barrel field, E1 barrel layer 6a has seemingly no coverage.
# 1310126712 Primary somatosensory area, barrel field, A2 barrel layer 1 has seemingly no coverage.
# 1464978040 Primary somatosensory area, barrel field, D6 barrel layer 4 has seemingly no coverage.
# 1639524986 Primary somatosensory area, barrel field, C4 barrel layer 3 has seemingly no coverage.
# 2551618170 Primary somatosensory area, barrel field, D5 barrel layer 3 has seemingly no coverage.
# 635 Posterior parietal association areas, layer 4 has seemingly no coverage.
# 631 Cortical amygdalar area has seemingly no coverage.
# 644 Somatomotor areas, layer 6a has seemingly no coverage.
# 646 Dorsal peduncular area, layer 5 has seemingly no coverage.
# 3320050311 Primary somatosensory area, barrel field, D1 barrel layer 5 has seemingly no coverage.
# 3946289800 Primary somatosensory area, barrel field, Delta barrel layer 3 has seemingly no coverage.
# 3049552521 Primary somatosensory area, mouth, layer 3 has seemingly no coverage.
# 647 Cortical amygdalar area, posterior part has seemingly no coverage.
# 3088876178 Agranular insular area, dorsal part, layer 3 has seemingly no coverage.
# 1677451927 Primary somatosensory area, barrel field, A3 barrel layer 6a has seemingly no coverage.
# 3456985752 Primary somatosensory area, barrel field, B2 barrel layer 2/3 has seemingly no coverage.
# 1454256797 Primary somatosensory area, lower limb, layer 2 has seemingly no coverage.
# 669 Visual areas has seemingly no coverage.
# 2197459620 Primary somatosensory area, barrel field, E5 barrel layer 6b has seemingly no coverage.
# 677 Visceral area has seemingly no coverage.
# 3582239403 Anterior cingulate area, ventral part, layer 3 has seemingly no coverage.
# 683 Posterior parietal association areas, layer 5 has seemingly no coverage.
# 686 Primary somatosensory area, layer 6a has seemingly no coverage.
# 688 Cerebral cortex has seemingly no coverage.
# 695 Cortical plate has seemingly no coverage.
# 3167765177 Primary somatosensory area, barrel field, C4 barrel layer 2 has seemingly no coverage.
# 1126601402 Primary somatosensory area, barrel field, B2 barrel layer 3 has seemingly no coverage.
# 12993 Somatosensory areas, layer 1 has seemingly no coverage.
# 12994 Somatosensory areas, layer 2/3 has seemingly no coverage.
# 12995 Somatosensory areas, layer 4 has seemingly no coverage.
# 12996 Somatosensory areas, layer 5 has seemingly no coverage.
# 12997 Somatosensory areas, layer 6a has seemingly no coverage.
# 12998 Somatosensory areas, layer 6b has seemingly no coverage.
# 712 Entorhinal area, medial part, dorsal zone, layer 4 has seemingly no coverage.
# 714 Orbital area has seemingly no coverage.
# 715 Entorhinal area, lateral part, layer 2a has seemingly no coverage.
# 719 Primary somatosensory area, layer 6b has seemingly no coverage.
# 723 Orbital area, lateral part has seemingly no coverage.
# 1496257237 Primary somatosensory area, barrel field, Beta barrel layer 5 has seemingly no coverage.
# 1344105173 Primary somatosensory area, barrel field, A1 barrel layer 1 has seemingly no coverage.
# 1673450198 Primary somatosensory area, barrel field, B2 barrel has seemingly no coverage.
# 1181035221 Primary somatosensory area, barrel field, E5 barrel layer 3 has seemingly no coverage.
# 1884779226 Primary somatosensory area, barrel field, D2 barrel layer 2/3 has seemingly no coverage.
# 731 Orbital area, medial part has seemingly no coverage.
# 726 Dentate gyrus has seemingly no coverage.
# 734 Dentate gyrus crest has seemingly no coverage.
# 738 Orbital area, ventral part has seemingly no coverage.
# 739 Anterior cingulate area, layer 5 has seemingly no coverage.
# 742 Dentate gyrus crest, molecular layer has seemingly no coverage.
# 746 Orbital area, ventrolateral part has seemingly no coverage.
# 747 Infralimbic area, layer 2 has seemingly no coverage.
# 484682475 Prosubiculum, dorsal part has seemingly no coverage.
# 1798728430 Primary somatosensory area, barrel field, E4 barrel layer 3 has seemingly no coverage.
# 751 Dentate gyrus crest, polymorph layer has seemingly no coverage.
# 484682479 Prosubiculum, dorsal part, molecular layer has seemingly no coverage.
# 1714819828 Primary somatosensory area, barrel field, C6 barrel layer 6b has seemingly no coverage.
# 484682483 Prosubiculum, dorsal part, pyramidal layer has seemingly no coverage.
# 758 Dentate gyrus crest, granule cell layer has seemingly no coverage.
# 2659044087 Primary somatosensory area, barrel field, C4 barrel layer 6a has seemingly no coverage.
# 3561503481 Primary somatosensory area, barrel field, Delta barrel layer 6a has seemingly no coverage.
# 484682487 Prosubiculum, dorsal part, stratum radiatum has seemingly no coverage.
# 764 Entorhinal area, lateral part, layer 2b has seemingly no coverage.
# 484682492 Prosubiculum, ventral part has seemingly no coverage.
# 766 Dentate gyrus lateral blade has seemingly no coverage.
# 2561915647 Anterior olfactory nucleus: Other has seemingly no coverage.
# 484682496 Prosubiculum, ventral part, molecular layer has seemingly no coverage.
# 2854337283 Temporal association areas, layer 3 has seemingly no coverage.
# 3299719941 Primary somatosensory area, barrel field, E4 barrel layer 4 has seemingly no coverage.
# 484682500 Prosubiculum, ventral part, pyramidal layer has seemingly no coverage.
# 775 Dentate gyrus lateral blade, molecular layer has seemingly no coverage.
# 484682504 Prosubiculum, ventral part, stratum radiatum has seemingly no coverage.
# 1447791371 Primary somatosensory area, barrel field, A3 barrel layer 2/3 has seemingly no coverage.
# 3054551821 Primary somatosensory area, barrel field, E2 barrel has seemingly no coverage.
# 1412541198 Primary somatosensory area, barrel field, D5 barrel has seemingly no coverage.
# 782 Dentate gyrus lateral blade, polymorph layer has seemingly no coverage.
# 790 Dentate gyrus lateral blade, granule cell layer has seemingly no coverage.
# 793 Primary somatosensory area, layer 1 has seemingly no coverage.
# 799 Dentate gyrus medial blade has seemingly no coverage.
# 801 Visual areas, layer 1 has seemingly no coverage.
# 807 Dentate gyrus medial blade, molecular layer has seemingly no coverage.
# 3527105324 Primary somatosensory area, barrel field, E2 barrel layer 6b has seemingly no coverage.
# 815 Dentate gyrus medial blade, polymorph layer has seemingly no coverage.
# 2590882612 Primary somatosensory area, barrel field, A3 barrel layer 2 has seemingly no coverage.
# 822 Retrohippocampal region has seemingly no coverage.
# 823 Dentate gyrus medial blade, granule cell layer has seemingly no coverage.
# 829 Subiculum, dorsal part, molecular layer has seemingly no coverage.
# 3118601025 Primary somatosensory area, barrel field, E5 barrel layer 4 has seemingly no coverage.
# 837 Subiculum, dorsal part, stratum radiatum has seemingly no coverage.
# 3894563657 Primary visual area, layer 3 has seemingly no coverage.
# 1024543562 Olfactory areas: Other has seemingly no coverage.
# 845 Subiculum, dorsal part, pyramidal layer has seemingly no coverage.
# 2815501138 Primary somatosensory area, barrel field, E6 barrel layer 2 has seemingly no coverage.
# 853 Subiculum, ventral part, molecular layer has seemingly no coverage.
# 3269661528 Orbital area, layer 2 has seemingly no coverage.
# 3413451609 Primary somatosensory area, barrel field, E7 barrel layer 2 has seemingly no coverage.
# 1013068637 Primary somatosensory area, barrel field, C1 barrel has seemingly no coverage.
# 2542216029 Supplemental somatosensory area, layer 3 has seemingly no coverage.
# 861 Subiculum, ventral part, stratum radiatum has seemingly no coverage.
# 865 Primary somatosensory area, layer 4 has seemingly no coverage.
# 3562601313 Primary somatosensory area, barrel field, B4 barrel layer 3 has seemingly no coverage.
# 870 Subiculum, ventral part, pyramidal layer has seemingly no coverage.
# 3095364455 Anterior cingulate area, dorsal part, layer 2 has seemingly no coverage.
# 1246610280 Primary somatosensory area, barrel field, C5 barrel layer 1 has seemingly no coverage.
# 879 Retrosplenial area, dorsal part has seemingly no coverage.
# 3591549811 Primary somatosensory area, nose, layer 2 has seemingly no coverage.
# 2949903222 Anterior cingulate area, layer 2 has seemingly no coverage.
# 886 Retrosplenial area, ventral part has seemingly no coverage.
# 894 Retrosplenial area, lateral agranular part has seemingly no coverage.
# 3289019263 Primary somatosensory area, barrel field, B1 barrel layer 6a has seemingly no coverage.
# 895 Ectorhinal area has seemingly no coverage.
# 909 Entorhinal area has seemingly no coverage.
# 913 Visual areas, layer 4 has seemingly no coverage.
# 2613674898 Primary somatosensory area, barrel field, E7 barrel layer 1 has seemingly no coverage.
# 918 Entorhinal area, lateral part has seemingly no coverage.
# 921 Primary somatosensory area, layer 5 has seemingly no coverage.
# 182305689 Primary somatosensory area, unassigned has seemingly no coverage.
# 922 Perirhinal area has seemingly no coverage.
# 2739084189 Primary somatosensory area, barrel field, B3 barrel layer 6b has seemingly no coverage.
# 3516629919 Ectorhinal area, layer 3 has seemingly no coverage.
# 1468793762 Primary somatosensory area, barrel field, E5 barrel has seemingly no coverage.
# 926 Entorhinal area, medial part, dorsal zone has seemingly no coverage.
# 934 Entorhinal area, medial part, ventral zone has seemingly no coverage.
# 937 Visual areas, layer 5 has seemingly no coverage.
# 942 Endopiriform nucleus has seemingly no coverage.
# 947 Somatomotor areas, layer 6b has seemingly no coverage.
# 1928393658 Primary somatosensory area, barrel field, E3 barrel layer 6b has seemingly no coverage.
# 2710463424 Primary somatosensory area, barrel field, D7 barrel layer 6b has seemingly no coverage.
# 2157528000 Primary somatosensory area, barrel field, E3 barrel layer 5 has seemingly no coverage.
# 2790124484 Prelimbic area, layer 3 has seemingly no coverage.
# 3139552203 Primary somatosensory area, barrel field, A3 barrel layer 4 has seemingly no coverage.
# 972 Prelimbic area has seemingly no coverage.
# 2236457933 Primary somatosensory area, barrel field, D8 barrel layer 5 has seemingly no coverage.
# 985 Primary motor area has seemingly no coverage.
# 2180527067 Primary somatosensory area, barrel field, B4 barrel layer 2/3 has seemingly no coverage.
# 1667660763 Primary somatosensory area, barrel field, C1 barrel layer 2/3 has seemingly no coverage.
# 3628159968 Primary somatosensory area, barrel field, D1 barrel layer 6a has seemingly no coverage.
# 993 Secondary motor area has seemingly no coverage.
# 2023633893 Primary somatosensory area, barrel field, D6 barrel layer 6a has seemingly no coverage.
# 3710667749 posteromedial visual area, layer 3 has seemingly no coverage.
# 999 Entorhinal area, lateral part, layer 2/3 has seemingly no coverage.
# 2064317417 Primary somatosensory area, barrel field, E7 barrel layer 5 has seemingly no coverage.
# 1002 Primary auditory area has seemingly no coverage.
# 3937412080 Somatosensory areas, layer 3 has seemingly no coverage.
# 3206763505 Mediomedial anterior visual area, layer 3 has seemingly no coverage.
# 1011 Dorsal auditory area has seemingly no coverage.
# 1018 Ventral auditory area has seemingly no coverage.
# 1463157755 Anterolateral visual area, layer 2 has seemingly no coverage.
# 1027 Posterior auditory area has seemingly no coverage.
# 2062992388 Primary somatosensory area, barrel field, C5 barrel has seemingly no coverage.
# 2768475141 Primary somatosensory area, barrel field, E3 barrel layer 3 has seemingly no coverage.
# 3521164295 Primary somatosensory area, barrel field, D3 barrel layer 2 has seemingly no coverage.
# 3840818183 Primary somatosensory area, barrel field, E4 barrel has seemingly no coverage.
# 3673895945 Primary somatosensory area, barrel field, D7 barrel layer 2 has seemingly no coverage.
# 1034 Taenia tecta, dorsal part, layer 1 has seemingly no coverage.
# 3920024588 Primary somatosensory area, barrel field, D7 barrel has seemingly no coverage.
# 2416897036 Cortical subplate: Other has seemingly no coverage.
# 1054221329 Primary somatosensory area, barrel field, Beta barrel layer 3 has seemingly no coverage.
# 1042 Taenia tecta, dorsal part, layer 2 has seemingly no coverage.
# 1926976537 Primary somatosensory area, barrel field, D2 barrel layer 3 has seemingly no coverage.
# 1050 Taenia tecta, dorsal part, layer 3 has seemingly no coverage.
# 1170723867 Primary somatosensory area, barrel field, D5 barrel layer 4 has seemingly no coverage.
# 1053 Anterior cingulate area, layer 2/3 has seemingly no coverage.
# 1057 Gustatory areas has seemingly no coverage.
# 1059 Taenia tecta, dorsal part, layer 4 has seemingly no coverage.
# 2369238059 Primary somatosensory area, barrel field, B3 barrel layer 5 has seemingly no coverage.
# 1067 Taenia tecta, ventral part, layer 1 has seemingly no coverage.
# 3683796018 Gustatory areas, layer 2 has seemingly no coverage.
# 3043750963 Primary somatosensory area, barrel field, E4 barrel layer 6a has seemingly no coverage.
# 1913328693 Primary somatosensory area, barrel field, D6 barrel layer 6b has seemingly no coverage.
# 1075 Taenia tecta, ventral part, layer 2 has seemingly no coverage.
# 3188360247 Primary somatosensory area, barrel field, E1 barrel layer 3 has seemingly no coverage.
# 1080 Hippocampal region has seemingly no coverage.
# 1082 Taenia tecta, ventral part, layer 3 has seemingly no coverage.
# 3360392253 Posterior parietal association areas, layer 3 has seemingly no coverage.
# 3329043535 Primary somatosensory area, barrel field, D2 barrel has seemingly no coverage.
# 2185403483 Primary somatosensory area, barrel field, E2 barrel layer 2 has seemingly no coverage.
# 1133 Entorhinal area, medial part, ventral zone, layer 5/6 has seemingly no coverage.
# 1792980078 Primary somatosensory area, barrel field, C5 barrel layer 4 has seemingly no coverage.
# 2341450864 Primary somatosensory area, barrel field, D5 barrel layer 2 has seemingly no coverage.
# 2358987890 Primary somatosensory area, barrel field, D7 barrel layer 2/3 has seemingly no coverage.
# 1140 Postpiriform transition area, layers 1 has seemingly no coverage.
# 1375046773 Cortical amygdalar area, posterior part, medial zone: Other has seemingly no coverage.
# 1141 Postpiriform transition area, layers 2 has seemingly no coverage.
# 1142 Postpiriform transition area, layers 3 has seemingly no coverage.
# 2933568634 Primary somatosensory area, barrel field, C6 barrel layer 1 has seemingly no coverage.
# 2615618683 Primary somatosensory area, barrel field, A1 barrel layer 2/3 has seemingly no coverage.
# 2374653061 Primary somatosensory area, barrel field, E5 barrel layer 5 has seemingly no coverage.
# 1370229894 Primary somatosensory area, barrel field, A1 barrel has seemingly no coverage.
# 1475527815 Primary somatosensory area, barrel field, E8 barrel layer 4 has seemingly no coverage.
# 3048883337 Primary somatosensory area, barrel field, Beta barrel layer 6b has seemingly no coverage.
# 2688781451 Primary somatosensory area, barrel field, Gamma barrel layer 6a has seemingly no coverage.
# 2072239244 Primary somatosensory area, barrel field, C2 barrel has seemingly no coverage.
# 1972094100 Primary somatosensory area, barrel field, D3 barrel layer 5 has seemingly no coverage.
# 3278290071 Primary somatosensory area, barrel field, Gamma barrel layer 5 has seemingly no coverage.
# 2692580507 Primary somatosensory area, barrel field, A3 barrel layer 5 has seemingly no coverage.
# 3718675619 Primary motor area, layer 2 has seemingly no coverage.
# 2026216612 Mediomedial anterior visual area, layer 2 has seemingly no coverage.
# 3132124329 Perirhinal area, layer 2 has seemingly no coverage.
# 2667261098 Primary somatosensory area, barrel field, Gamma barrel layer 3 has seemingly no coverage.
# 1093211310 Primary somatosensory area, barrel field, C3 barrel layer 6b has seemingly no coverage.
# 3895794866 Primary somatosensory area, barrel field, Beta barrel layer 4 has seemingly no coverage.
# 1160721590 Anterior area, layer 3 has seemingly no coverage.
# 3719447735 Primary somatosensory area, barrel field, C6 barrel layer 3 has seemingly no coverage.
# 2558258359 Primary somatosensory area, barrel field, D1 barrel layer 2 has seemingly no coverage.
# 3970522306 Primary somatosensory area, barrel field, Beta barrel layer 2 has seemingly no coverage.
# 2841658580 Primary somatosensory area, barrel field, D3 barrel layer 2/3 has seemingly no coverage.
# 3877358805 Primary somatosensory area, barrel field, C3 barrel layer 4 has seemingly no coverage.
# 2196657368 Primary somatosensory area, barrel field, B1 barrel layer 2 has seemingly no coverage.
# 2189208794 Visceral area, layer 3 has seemingly no coverage.
# 3853526235 Primary somatosensory area, barrel field, B2 barrel layer 1 has seemingly no coverage.
# 3092405473 Primary somatosensory area, barrel field, E5 barrel layer 2 has seemingly no coverage.
# 1582478571 Primary somatosensory area, barrel field, D5 barrel layer 6b has seemingly no coverage.
# 2544082156 posteromedial visual area, layer 2 has seemingly no coverage.
# 1877482733 Primary somatosensory area, barrel field, D7 barrel layer 1 has seemingly no coverage.
# 3192952047 Retrosplenial area, lateral agranular part, layer 2 has seemingly no coverage.
# 2927119608 Primary auditory area, layer 2 has seemingly no coverage.
# 3966633210 Primary somatosensory area, barrel field, B2 barrel layer 4 has seemingly no coverage.
# 1125438717 Primary somatosensory area, barrel field, C3 barrel layer 2/3 has seemingly no coverage.
# 2668242174 Perirhinal area, layer 3 has seemingly no coverage.
# 2438939909 Primary somatosensory area, barrel field, Delta barrel has seemingly no coverage.
# 3808183566 Laterointermediate area, layer 2 has seemingly no coverage.
# 1645194511 Anteromedial visual area, layer 2 has seemingly no coverage.
# 2629778705 Primary somatosensory area, barrel field, C3 barrel layer 2 has seemingly no coverage.
# 1456682260 Primary somatosensory area, barrel field, B4 barrel layer 2 has seemingly no coverage.
# 3085221154 Primary somatosensory area, barrel field, C4 barrel layer 5 has seemingly no coverage.
# 1209357605 Postpiriform transition area: Other has seemingly no coverage.
# 1082141991 Primary somatosensory area, barrel field, C2 barrel layer 1 has seemingly no coverage.
# 3652474151 Primary somatosensory area, barrel field, D8 barrel layer 4 has seemingly no coverage.
# 3999683881 Primary somatosensory area, barrel field, E4 barrel layer 2/3 has seemingly no coverage.
# 3748961581 Primary somatosensory area, barrel field, E2 barrel layer 1 has seemingly no coverage.
# 3137025327 Primary somatosensory area, barrel field, Alpha barrel layer 5 has seemingly no coverage.
# 1549069626 Primary somatosensory area, barrel field, C4 barrel layer 4 has seemingly no coverage.
# 1431942459 Posterolateral visual area, layer 3 has seemingly no coverage.
# 3808433473 Primary somatosensory area, unassigned, layer 2 has seemingly no coverage.
# 3803368771 Orbital area, lateral part, layer 2 has seemingly no coverage.
# 1005899076 Primary somatosensory area, barrel field, D8 barrel layer 6b has seemingly no coverage.
# 1071521092 Primary somatosensory area, barrel field, E1 barrel has seemingly no coverage.
# 2225157452 Primary somatosensory area, barrel field, E7 barrel layer 3 has seemingly no coverage.
# 3338653017 Primary somatosensory area, barrel field, D7 barrel layer 5 has seemingly no coverage.
# 3055000922 Primary somatosensory area, barrel field, D8 barrel has seemingly no coverage.
# 2906756445 Somatomotor areas, layer 3 has seemingly no coverage.
# 1446874462 Primary somatosensory area, barrel field, A2 barrel layer 2/3 has seemingly no coverage.
# 3685934448 Primary somatosensory area, barrel field, A2 barrel layer 4 has seemingly no coverage.
# 2803418480 Primary somatosensory area, barrel field, E1 barrel layer 2/3 has seemingly no coverage.
# 1510133109 Primary somatosensory area, barrel field, E7 barrel layer 6b has seemingly no coverage.
# 1171320182 Primary somatosensory area, barrel field, Gamma barrel has seemingly no coverage.
# 3403314552 Mediomedial posterior visual area, layer 3 has seemingly no coverage.
# 2964598138 Primary somatosensory area, barrel field, E1 barrel layer 5 has seemingly no coverage.
# 3556494715 Primary somatosensory area, barrel field, C5 barrel layer 5 has seemingly no coverage.
# 1624778115 Primary somatosensory area, barrel field, E8 barrel has seemingly no coverage.
# 3309772165 Primary somatosensory area, barrel field, E3 barrel layer 6a has seemingly no coverage.
# 3670777223 Primary somatosensory area, barrel field, Alpha barrel layer 6b has seemingly no coverage.
# 3893800328 Gustatory areas, layer 3 has seemingly no coverage.
# 2511156654 Secondary motor area, layer 3 has seemingly no coverage.
# 1165809076 Primary auditory area, layer 3 has seemingly no coverage.
# 2152572352 Primary somatosensory area, barrel field, Beta barrel layer 6a has seemingly no coverage.
# 2937437636 Primary somatosensory area, barrel field, C3 barrel has seemingly no coverage.
# 3571205574 Primary somatosensory area, barrel field, D4 barrel layer 6a has seemingly no coverage.
# 3653590473 Orbital area, ventrolateral part, layer 2 has seemingly no coverage.
# 3927629261 Lateral visual area, layer 2 has seemingly no coverage.
# 2683995601 Primary visual area, layer 2 has seemingly no coverage.
# 1890964946 Primary somatosensory area, upper limb, layer 3 has seemingly no coverage.
# 3134535128 Primary somatosensory area, barrel field, E8 barrel layer 2/3 has seemingly no coverage.
# 3890169311 Primary somatosensory area, barrel field, B4 barrel layer 5 has seemingly no coverage.
# 1787178465 Primary somatosensory area, barrel field, D5 barrel layer 2/3 has seemingly no coverage.
# 3913053667 Primary somatosensory area, barrel field, B1 barrel layer 2/3 has seemingly no coverage.
# 2743616995 Primary somatosensory area, barrel field, C3 barrel layer 6a has seemingly no coverage.
# 2292194787 Anteromedial visual area, layer 3 has seemingly no coverage.
# 1466095084 Cortical amygdalar area, anterior part: Other has seemingly no coverage.
# 1743009264 Primary somatosensory area, barrel field, D2 barrel layer 1 has seemingly no coverage.
# 2567067139 Primary somatosensory area, barrel field, D4 barrel layer 2 has seemingly no coverage.
# 2384899589 Primary somatosensory area, barrel field, D7 barrel layer 6a has seemingly no coverage.
# 2336071181 Supplemental somatosensory area, layer 2 has seemingly no coverage.
# 2835688982 Primary somatosensory area, barrel field, layer 2 has seemingly no coverage.
# 2449182232 Prosubiculum: Other has seemingly no coverage.
# 1406402073 Primary somatosensory area, barrel field, D8 barrel layer 1 has seemingly no coverage.
# 2300544548 Posterior parietal association areas, layer 2 has seemingly no coverage.
# 1598869030 Posterior auditory area, layer 3 has seemingly no coverage.
# 1258169895 Primary somatosensory area, barrel field, A2 barrel layer 6b has seemingly no coverage.
# 1666373161 Primary somatosensory area, barrel field, E6 barrel layer 1 has seemingly no coverage.
# 1843338795 Primary somatosensory area, barrel field, C2 barrel layer 6a has seemingly no coverage.
# 3173729836 Primary somatosensory area, barrel field, Alpha barrel layer 2 has seemingly no coverage.
# 1792026161 Subiculum: Other has seemingly no coverage.
# 2151167540 Primary somatosensory area, barrel field, C4 barrel layer 1 has seemingly no coverage.
# 1087129144 Laterolateral anterior visual area, layer 2 has seemingly no coverage.
# 1897248316 Primary somatosensory area, barrel field, Alpha barrel layer 2/3 has seemingly no coverage.
# 3880590912 Primary somatosensory area, barrel field, C5 barrel layer 2/3 has seemingly no coverage.
# 3302405705 Primary somatosensory area, barrel field, D3 barrel layer 6a has seemingly no coverage.
# 1667278413 Primary somatosensory area, barrel field, C3 barrel layer 5 has seemingly no coverage.
# 3859818063 Primary somatosensory area, barrel field, D4 barrel layer 4 has seemingly no coverage.
# 3116469840 Primary somatosensory area, barrel field, A1 barrel layer 2 has seemingly no coverage.
# 2835342929 Primary somatosensory area, barrel field, Alpha barrel layer 1 has seemingly no coverage.
# 2658756176 Primary somatosensory area, barrel field, E6 barrel layer 4 has seemingly no coverage.
# 1992072790 Cortical amygdalar area, posterior part, lateral zone: Other has seemingly no coverage.
# 2897348183 Anterior cingulate area, ventral part, layer 2 has seemingly no coverage.
# 3575805529 Primary somatosensory area, barrel field, A2 barrel layer 5 has seemingly no coverage.
# 2915675742 Primary somatosensory area, barrel field, E8 barrel layer 6a has seemingly no coverage.
# 3962734174 Lateral visual area, layer 3 has seemingly no coverage.
# 2439179873 Temporal association areas, layer 2 has seemingly no coverage.
# 3986345576 Primary somatosensory area, barrel field, B1 barrel layer 3 has seemingly no coverage.
# 1951878763 Primary somatosensory area, barrel field, E7 barrel layer 2/3 has seemingly no coverage.
# 3188993656 Primary somatosensory area, barrel field, C2 barrel layer 5 has seemingly no coverage.
# 1521759875 Primary somatosensory area, barrel field, Beta barrel has seemingly no coverage.
# 1507784331 Primary somatosensory area, barrel field, E1 barrel layer 6b has seemingly no coverage.
# 1311366798 Primary somatosensory area, barrel field, B2 barrel layer 2 has seemingly no coverage.
# 1876807310 Primary somatosensory area, barrel field, D3 barrel layer 3 has seemingly no coverage.
# 2782023316 Postrhinal area, layer 2 has seemingly no coverage.
# 3291535006 Primary somatosensory area, barrel field, C2 barrel layer 6b has seemingly no coverage.
# 2563782304 Primary somatosensory area, barrel field, C1 barrel layer 3 has seemingly no coverage.
# 2795738785 Primary somatosensory area, barrel field, E3 barrel layer 2 has seemingly no coverage.
# 2260827822 Primary somatosensory area, trunk, layer 3 has seemingly no coverage.
# 3964792502 Visceral area, layer 2 has seemingly no coverage.
# 2951747260 Primary somatosensory area, lower limb, layer 3 has seemingly no coverage.
# 3331415743 Primary somatosensory area, barrel field, E6 barrel layer 6b has seemingly no coverage.
# 1588504257 Primary somatosensory area, barrel field, D4 barrel layer 5 has seemingly no coverage.
# 2845253318 Anterolateral visual area, layer 3 has seemingly no coverage.
# 3582777032 Rostrolateral lateral visual area, layer 3 has seemingly no coverage.
# 3026302666 Primary somatosensory area, barrel field, E5 barrel layer 6a has seemingly no coverage.
# 1149652689 Primary somatosensory area, barrel field, D5 barrel layer 6a has seemingly no coverage.
# 480149202 Rostrolateral lateral visual area has seemingly no coverage.
# 312782546 Anterior area has seemingly no coverage.
# 480149206 Rostrolateral lateral visual area, layer 1 has seemingly no coverage.
# 2102386393 Primary somatosensory area, mouth, layer 2 has seemingly no coverage.
# 480149210 Rostrolateral lateral visual area, layer 2/3 has seemingly no coverage.
# 2460702429 Primary somatosensory area, barrel field, C4 barrel layer 2/3 has seemingly no coverage.
# 480149214 Rostrolateral lateral visual area, layer 4 has seemingly no coverage.
# 480149218 Rostrolateral lateral visual area, layer 5 has seemingly no coverage.
# 3545403109 Primary somatosensory area, barrel field, E2 barrel layer 5 has seemingly no coverage.
# 480149222 Rostrolateral lateral visual area, layer 6a has seemingly no coverage.
# 480149226 Rostrolateral lateral visual area, layer 6b has seemingly no coverage.
# 480149230 Laterolateral anterior visual area has seemingly no coverage.
# 312782574 Laterointermediate area has seemingly no coverage.
# 1105483506 Primary somatosensory area, barrel field, C5 barrel layer 3 has seemingly no coverage.
# 480149234 Laterolateral anterior visual area, layer 1 has seemingly no coverage.
# 3453175542 Primary somatosensory area, barrel field, D8 barrel layer 3 has seemingly no coverage.
# 480149238 Laterolateral anterior visual area, layer 2/3 has seemingly no coverage.
# 2811301625 Primary somatosensory area, barrel field, E3 barrel has seemingly no coverage.
# 480149242 Laterolateral anterior visual area, layer 4 has seemingly no coverage.
# 1373744894 Primary somatosensory area, barrel field, D8 barrel layer 2/3 has seemingly no coverage.
# 480149246 Laterolateral anterior visual area, layer 5 has seemingly no coverage.
# 480149250 Laterolateral anterior visual area, layer 6a has seemingly no coverage.
# 480149254 Laterolateral anterior visual area, layer 6b has seemingly no coverage.
# 480149258 Mediomedial anterior visual area has seemingly no coverage.
# 480149262 Mediomedial anterior visual area, layer 1 has seemingly no coverage.
# 480149266 Mediomedial anterior visual area, layer 2/3 has seemingly no coverage.
# 480149270 Mediomedial anterior visual area, layer 4 has seemingly no coverage.
# 1427961626 Primary somatosensory area, barrel field, E5 barrel layer 1 has seemingly no coverage.
# 480149274 Mediomedial anterior visual area, layer 5 has seemingly no coverage.
# 480149278 Mediomedial anterior visual area, layer 6a has seemingly no coverage.
# 480149282 Mediomedial anterior visual area, layer 6b has seemingly no coverage.
# 312782628 Postrhinal area has seemingly no coverage.
# 480149286 Mediomedial posterior visual area has seemingly no coverage.
# 2593521448 Primary somatosensory area, barrel field, A2 barrel layer 3 has seemingly no coverage.
# 480149290 Mediomedial posterior visual area, layer 1 has seemingly no coverage.
# 480149294 Mediomedial posterior visual area, layer 2/3 has seemingly no coverage.
# 3416776496 Primary somatosensory area, barrel field, B2 barrel layer 6b has seemingly no coverage.
# 1588741938 Primary somatosensory area, barrel field, D6 barrel has seemingly no coverage.
# 480149298 Mediomedial posterior visual area, layer 4 has seemingly no coverage.
# 1626685236 Primary somatosensory area, barrel field, B3 barrel has seemingly no coverage.
# 480149302 Mediomedial posterior visual area, layer 5 has seemingly no coverage.
# 2732283703 Primary somatosensory area, barrel field, A3 barrel has seemingly no coverage.
# 480149306 Mediomedial posterior visual area, layer 6a has seemingly no coverage.
# 1430875964 Rostrolateral visual area, layer 2 has seemingly no coverage.
# 480149310 Mediomedial posterior visual area, layer 6b has seemingly no coverage.
# 3859877696 Primary somatosensory area, barrel field, D1 barrel layer 3 has seemingly no coverage.
# 2427348802 Primary somatosensory area, barrel field, D4 barrel layer 3 has seemingly no coverage.
# 3331790659 Primary somatosensory area, barrel field, E3 barrel layer 2/3 has seemingly no coverage.
# 480149314 Medial visual area has seemingly no coverage.
# 480149318 Medial visual area, layer 1 has seemingly no coverage.
# 1337935688 Primary somatosensory area, barrel field, C1 barrel layer 1 has seemingly no coverage.
# 480149322 Medial visual area, layer 2/3 has seemingly no coverage.
# 480149326 Medial visual area, layer 4 has seemingly no coverage.
# 480149330 Medial visual area, layer 5 has seemingly no coverage.
# 480149334 Medial visual area, layer 6a has seemingly no coverage.
# 480149338 Medial visual area, layer 6b has seemingly no coverage.
# 2358040414 Main olfactory bulb: Other has seemingly no coverage.
# 2406188897 Primary somatosensory area, barrel field, Alpha barrel layer 6a has seemingly no coverage.
# 3985188708 Primary somatosensory area, barrel field, C6 barrel layer 5 has seemingly no coverage.
# 2980820846 Primary somatosensory area, barrel field, E1 barrel layer 2 has seemingly no coverage.
# 3783583602 Primary somatosensory area, barrel field, Beta barrel layer 2/3 has seemingly no coverage.
# 1456398198 Primary somatosensory area, barrel field, Delta barrel layer 5 has seemingly no coverage.
# 2952544119 Parasubiculum: Other has seemingly no coverage.
# 1947266943 Primary somatosensory area, barrel field, D6 barrel layer 2/3 has seemingly no coverage.
# 2360313730 Primary somatosensory area, barrel field, E4 barrel layer 5 has seemingly no coverage.
# 2812530569 Primary somatosensory area, barrel field, B2 barrel layer 5 has seemingly no coverage.
# 3128223634 Primary somatosensory area, barrel field, E2 barrel layer 2/3 has seemingly no coverage.
# 3250982806 Agranular insular area, dorsal part, layer 2 has seemingly no coverage.
# 2063775638 Postsubiculum: Other has seemingly no coverage.
# 3651721123 Primary somatosensory area, barrel field, A2 barrel has seemingly no coverage.
# 2862362532 Anterior cingulate area, dorsal part, layer 3 has seemingly no coverage.
# 3314370483 Retrosplenial area, ventral part, layer 3 has seemingly no coverage.
# 2012716980 Orbital area, medial part, layer 3 has seemingly no coverage.
# 2168807353 Primary somatosensory area, barrel field, Alpha barrel layer 4 has seemingly no coverage.
# 2436888515 Primary somatosensory area, barrel field, A1 barrel layer 5 has seemingly no coverage.
# 2691358660 Primary somatosensory area, layer 2 has seemingly no coverage.
# 2866280389 Primary somatosensory area, barrel field, C1 barrel layer 6b has seemingly no coverage.
# 3434166213 Primary somatosensory area, barrel field, Delta barrel layer 2/3 has seemingly no coverage.
# 1037481934 Orbital area, lateral part, layer 3 has seemingly no coverage.
# 2413172686 Orbital area, ventrolateral part, layer 3 has seemingly no coverage.
# 3404738524 Primary somatosensory area, barrel field, C4 barrel has seemingly no coverage.
# 2108774369 Primary somatosensory area, barrel field, D1 barrel layer 4 has seemingly no coverage.
# 1171261412 Primary somatosensory area, barrel field, D1 barrel has seemingly no coverage.
# 1641347046 Primary somatosensory area, barrel field, B2 barrel layer 6a has seemingly no coverage.
# 3807479791 Primary somatosensory area, barrel field, E1 barrel layer 1 has seemingly no coverage.
# 3513655281 Primary somatosensory area, barrel field, Gamma barrel layer 2/3 has seemingly no coverage.

# %%
#More sanity checks
crb_leaves = []
for leaf in cerebellum:
    pacellations_sets = parcellation_annotation[parcellation_annotation['label_numbers'] == leaf]
    parcallation = pacellations_sets[pacellations_sets['parcellation_term_set_name'] == 'substructure']
    if parcallation.shape[0] == 1:
        crb_leaves.append(parcallation['cluster_as_filename'].iloc[0])
    else:
        print(str(leaf) + " " + region_map.get(leaf, "name", with_ascendants=False))
# Out:
# 519 Cerebellar nuclei
# 528 Cerebellar cortex
# 1073 Hemispheric regions
# 1143 Cerebellar cortex, granular layer
# 1144 Cerebellar cortex, molecular layer
# 1145 Cerebellar cortex, Purkinje layer
# 645 Vermal regions
# 920 Central lobule
# 928 Culmen
# 3092369320 Cerebellum: Other
# 10714 Lobule IV, granular layer
# 10715 Lobule IV, Purkinje layer
# 10716 Lobule IV, molecular layer
# 10717 Lobule V, granular layer
# 10718 Lobule V, Purkinje layer
# 992 Lobule IV
# 10719 Lobule V, molecular layer
# 1001 Lobule V
# 1017 Ansiform lobule

# %% [markdown]
# ```Python
#
# 519 Cerebellar nuclei
# 528 Cerebellar cortex
# 1073 Hemispheric regions
# 1143 Cerebellar cortex, granular layer
# 1144 Cerebellar cortex, molecular layer
# 1145 Cerebellar cortex, Purkinje layer
# 645 Vermal regions
# 920 Central lobule
# 928 Culmen
# 10714 Lobule IV, granular layer
# 10715 Lobule IV, Purkinje layer
# 10716 Lobule IV, molecular layer
# 10717 Lobule V, granular layer
# 10718 Lobule V, Purkinje layer
# 992 Lobule IV
# 10719 Lobule V, molecular layer
# 1001 Lobule V
# 1017 Ansiform lobule
#
# These regions are either leaf regions but they are not present in CCFv3a/0 or they are not leaf regions

# %%
#no CTX or CRB keys should be printed. Only regions with multiple solutions, which is taken care of elsewhere

ctx_keys = []
crb_keys = []
else_keys = []
for key in combined_result_dataframes.keys():
    cluster_as_filename = parcellation_annotation[parcellation_annotation['cluster_as_filename'] == key]
    cluster = cluster_as_filename[cluster_as_filename['parcellation_term_set_name'] == 'substructure']
    #This != part is for ambiguous regions:
    if cluster.shape[0] != 1:
        print(key )
        for key_name in cluster['cluster_as_filename'].values:
            # Add the element to else_keys list
            else_keys.append(key_name)
    elif cluster['label_numbers'].iloc[0] in cerebral_cortex:
        ctx_keys.append(cluster['cluster_as_filename'].iloc[0])
    elif cluster['label_numbers'].iloc[0] in cerebellum:
        crb_keys.append(cluster['cluster_as_filename'].iloc[0])
    else:
        else_keys.append(cluster['cluster_as_filename'].iloc[0])

#remove duplicates if there's any (in else there is)
else_keys = list(dict.fromkeys(else_keys))
crb_keys = list(dict.fromkeys(crb_keys))
ctx_keys = list(dict.fromkeys(ctx_keys))

print(len(ctx_keys), len(crb_keys), len(else_keys), )
# Out:
# fa
# icp
# sV
# scp
# st
# 309 54 340

# %%
#We can see that we only have 308 regions out of 567 and 22 out of 88. 
len(cerebral_cortex), len(cerebellum), len(neurontypes), len(exctypes), len(inhtypes)
# Out:
# (989, 89, 5205, 2619, 2511)

# %% [markdown]
# ### GLOBAL Scaling will take place.
# - We scale down CTX/ELSE uniformly, while we only scale up CRB excitatory cells
# #- We scale down CTX/ELSE uniformly, while we only scale up CRB neuron + glia cells
# - We scale ALL NON-NEURONS across all REGIONS uniformly.

# %%
# %%time
combined_result_dataframes_copy = copy.deepcopy(combined_result_dataframes)
# del scaled_combined_result_dataframes
scaled_combined_result_dataframes = {}

#Do the scaling: CTX: neurons only, CRB: EXC only, ELSE: neuron only
for key, df in combined_result_dataframes_copy.items():
    #Scale only the neurons:
    if key in ctx_keys:
        # Select rows where the value is in neurontypes
        mask = df.index.isin(neurontypes)
        
        # Divide only selected rows by scaling factor for CTX
        df.loc[mask, 'density_mm3'] /= (mfish_ctx/total_ctx)
        scaled_combined_result_dataframes[key] = df
        del mask

        # Select rows where the value is in NON-N
        mask = df.index.isin(nonneurontypes)
        
        # Divide only selected rows by scaling factor for CTX NON_N
        df.loc[mask, 'density_mm3'] /=  (mfish_nonneuron/total_nonneuron) #Change later
        scaled_combined_result_dataframes[key] = df
        del mask
        del df        
        
    elif key in crb_keys:
        # Select rows where the value is in  exc types
        mask = df.index.isin(exctypes)
        # Select rows where the value is in neuron+glia types
        # combined = np.concatenate((exctypes, glia))
        # mask = df.index.isin(combined)
        
        # Divide only selected rows by scaling factor for CB
        df.loc[mask, 'density_mm3'] /= (mfish_crb/total_crb)
        scaled_combined_result_dataframes[key] = df        
        #print(df)
        del mask

        # Select rows where the value is in NON-N
        mask = df.index.isin(nonneurontypes)
        
        # Divide only selected rows by scaling factor for CB NON_N
        df.loc[mask, 'density_mm3'] /=  (mfish_nonneuron/total_nonneuron) #Change later
        scaled_combined_result_dataframes[key] = df
        del mask
        del df        
        
    elif key in else_keys:
        # Select rows where the value is in neurontypes
        mask = df.index.isin(neurontypes)
        
        # Divide only selected rows by scaling factor for REST
        df.loc[mask, 'density_mm3'] /= (mfish_rest/total_rest)
        scaled_combined_result_dataframes[key] = df        
        del mask

        # Select rows where the value is in NON-N
        mask = df.index.isin(nonneurontypes)
        
        # Divide only selected rows by scaling factor for REST NON_N
        df.loc[mask, 'density_mm3'] /=  (mfish_nonneuron/total_nonneuron) #Change later
        scaled_combined_result_dataframes[key] = df
        del mask
        del df        
        
    else:
        print(key, "is an Issue!")


del combined_result_dataframes_copy
# Out:
# CPU times: user 956 ms, sys: 9.17 ms, total: 965 ms
# Wall time: 956 ms

# %% [markdown]
# ACAd1 is a CTX region, AAA is from rest, ANcr1, UVU is from CRB

# %%
#Rest
scaled_combined_result_dataframes['AAA'], combined_result_dataframes['AAA']
# Out:
# (                               density_mm3
#  cluster
#  0023 L5/6 IT TPE-ENT Glut_1     392.495046
#  0093 L4/5 IT CTX Glut_4         249.769575
#  0150 L2/3 IT PIR-ENTl Glut_3     35.681368
#  0205 MEA Slc17a7 Glut_2        2604.739852
#  0207 MEA Slc17a7 Glut_2          35.681368
#  ...                                    ...
#  5309 Endo NN_1                 4190.094516
#  5310 Endo NN_1                11463.466129
#  5311 Endo NN_1                 1067.288226
#  5312 Microglia NN_1            3241.393871
#  5314 BAM NN_1                    79.058387
#
#  [412 rows x 1 columns],
#                                 density_mm3
#  cluster
#  0023 L5/6 IT TPE-ENT Glut_1     462.320851
#  0093 L4/5 IT CTX Glut_4         294.204178
#  0150 L2/3 IT PIR-ENTl Glut_3     42.029168
#  0205 MEA Slc17a7 Glut_2        3068.129282
#  0207 MEA Slc17a7 Glut_2          42.029168
#  ...                                    ...
#  5309 Endo NN_1                 4455.091834
#  5310 Endo NN_1                12188.458790
#  5311 Endo NN_1                 1134.787543
#  5312 Microglia NN_1            3446.391796
#  5314 BAM NN_1                    84.058336
#
#  [412 rows x 1 columns])

# %%
#CTX
scaled_combined_result_dataframes['ACAd1'], combined_result_dataframes['ACAd1']
# Out:
# (                             density_mm3
#  cluster
#  0023 L5/6 IT TPE-ENT Glut_1    19.171176
#  0077 L4/5 IT CTX Glut_2        19.171176
#  0090 L4/5 IT CTX Glut_4        19.171176
#  0094 L4/5 IT CTX Glut_4        19.171176
#  0105 L2/3 IT CTX Glut_1      3757.550579
#  ...                                  ...
#  5311 Endo NN_1               2372.208143
#  5312 Microglia NN_1          5410.299273
#  5314 BAM NN_1                 291.323807
#  5318 DC NN_1                   41.617687
#  5319 B cells NN_1              41.617687
#
#  [110 rows x 1 columns],
#                               density_mm3
#  cluster
#  0023 L5/6 IT TPE-ENT Glut_1    44.249746
#  0077 L4/5 IT CTX Glut_2        44.249746
#  0090 L4/5 IT CTX Glut_4        44.249746
#  0094 L4/5 IT CTX Glut_4        44.249746
#  0105 L2/3 IT CTX Glut_1      8672.950131
#  ...                                  ...
#  5311 Endo NN_1               2522.235497
#  5312 Microglia NN_1          5752.466923
#  5314 BAM NN_1                 309.748219
#  5318 DC NN_1                   44.249746
#  5319 B cells NN_1              44.249746
#
#  [110 rows x 1 columns])

# %%
#Cerebellum
scaled_combined_result_dataframes['ANcr1molecularlayer'], combined_result_dataframes['ANcr1molecularlayer']
# Out:
# (                          density_mm3
#  cluster
#  5000 CBN Dmbx1 Gaba_1        7.720368
#  5175 DCO Il22 Gly-Gaba_3     3.860184
#  5177 CB PLI Gly-Gaba_1     208.449943
#  5178 CB PLI Gly-Gaba_1     741.155353
#  5179 CB PLI Gly-Gaba_1      54.042578
#  ...                               ...
#  5316 DC NN_1                 3.630573
#  5317 DC NN_1                 3.630573
#  5318 DC NN_1                 3.630573
#  5319 B cells NN_1           21.783438
#  5322 T cells NN_4            3.630573
#
#  [75 rows x 1 columns],
#                            density_mm3
#  cluster
#  5000 CBN Dmbx1 Gaba_1        7.720368
#  5175 DCO Il22 Gly-Gaba_3     3.860184
#  5177 CB PLI Gly-Gaba_1     208.449943
#  5178 CB PLI Gly-Gaba_1     741.155353
#  5179 CB PLI Gly-Gaba_1      54.042578
#  ...                               ...
#  5316 DC NN_1                 3.860184
#  5317 DC NN_1                 3.860184
#  5318 DC NN_1                 3.860184
#  5319 B cells NN_1           23.161105
#  5322 T cells NN_4            3.860184
#
#  [75 rows x 1 columns])

# %%
len(scaled_combined_result_dataframes.keys()), len(combined_result_dataframes.keys())
# Out:
# (703, 703)

# %%
# Assuming 'total_cells' is your dictionary of DataFrames
with open(f'{folder}scaled_densities_global_only.pickle', 'wb') as f:
    pickle.dump(scaled_combined_result_dataframes, f)

print(f"Saved here: {folder}")
# Out:
# Saved here: /gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/

# %% [markdown]
# The file is a scaled version of combined_result_dataframes (normal name in other parts of the pipeline)

# %%
#We can't use csv files with densities as those are not scaled
root_folder = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/'

file = os.path.join( root_folder, 'scaled_densities_global_only.pickle' )
#Load region id volumes from volume_calc_from_template.ipynb
with open(file, 'rb') as pickle_file:
    scaled_combined_result_dataframes = pickle.load(pickle_file)
print("Loaded pickle file.")
# Out:
# Loaded pickle file.

# %%
#You can save the data as  1 df /t-type as a dictionary

shuffled_combined_dataframes = create_combined_dataframe(scaled_combined_result_dataframes)

# Reorder the dataframes alphabetically by key
sorted_data = {k: shuffled_combined_dataframes[k] for k in sorted(shuffled_combined_dataframes)}

# %%
# Assuming 'total_cells' is your dictionary of DataFrames
with open(f'{folder}scaled_densities_global_only_t_types_as_keys.pickle', 'wb') as f:
    pickle.dump(sorted_data, f)

print(f"Saved here: {folder}")
# Out:
# Saved here: /gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/

# %%
sorted_keys = sorted(shuffled_combined_dataframes)
last_key = sorted_keys[-1]
last_key
# Out:
# '5322 T cells NN_4'

# %%
pd.options.display.float_format = '{:.2f}'.format
df_sorted = scaled_combined_result_dataframes['UVUgranularlayer'].sort_values(by='density_mm3', ascending=False)
df_sorted
# Out:
#                         density_mm3
# cluster
# 5201 CB Granule Glut_2   1509904.50
# 5200 CB Granule Glut_2    119838.67
# 5202 DCO UBC Glut_1         7215.42
# 5198 CB Granule Glut_1      7215.42
# 5310 Endo NN_1              7148.62
# ...                             ...
# 5281 NFOL NN_2                25.00
# 5275 COP NN_1                 25.00
# 5272 COP NN_1                 25.00
# 5279 NFOL NN_2                25.00
# 5313 BAM NN_1                 25.00
#
# [64 rows x 1 columns]

# %%
# Iterate through the dictionary keys
for key, df in combined_result_dataframes.items():
    # Check if the key contains 'granularlayer'
    if 'granularlayer' in key:
        # Find the index of the highest value in the 'density_mm3' column
        max_density_index = df['density_mm3'].idxmax()
        # Find the highest value of the 'density_mm3' column
        max_density = df.loc[max_density_index, 'density_mm3']
        print(f"Highest density for {key} at index {max_density_index}: {max_density}")
# Out:
# Highest density for ANcr1granularlayer at index 5201 CB Granule Glut_2: 66541.85404643802
# Highest density for ANcr2granularlayer at index 5201 CB Granule Glut_2: 45524.712402293146
# Highest density for CENT2granularlayer at index 5201 CB Granule Glut_2: 159963.9810137208
# Highest density for CENT3granularlayer at index 5201 CB Granule Glut_2: 131770.58939066585
# Highest density for COPYgranularlayer at index 5201 CB Granule Glut_2: 51712.158808933
# Highest density for CUL45granularlayer at index 5201 CB Granule Glut_2: 90003.01003139034
# Highest density for DECgranularlayer at index 5201 CB Granule Glut_2: 46980.34586977127
# Highest density for FLgranularlayer at index 5201 CB Granule Glut_2: 42846.53895355265
# Highest density for FOTUgranularlayer at index 5201 CB Granule Glut_2: 46405.02354788069
# Highest density for LINGgranularlayer at index 5201 CB Granule Glut_2: 51953.56738391846
# Highest density for NODgranularlayer at index 5201 CB Granule Glut_2: 83100.52138014486
# Highest density for PFLgranularlayer at index 5201 CB Granule Glut_2: 53443.985222052914
# Highest density for PRMgranularlayer at index 5201 CB Granule Glut_2: 42250.56675621818
# Highest density for PYRgranularlayer at index 5201 CB Granule Glut_2: 67603.59960004444
# Highest density for SIMgranularlayer at index 5201 CB Granule Glut_2: 96999.92310311872
# Highest density for UVUgranularlayer at index 5201 CB Granule Glut_2: 127910.06697140427

# %% [raw]
# fetypes = pd.read_csv("/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/mean_bbp_atlas_densities.csv")
# fttypes = pd.read_csv("/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/mean_tr_densities.csv")
#
# # Drop rows where all specified columns are NaN
# columns_to_check = ['neurons_mm3', 'inh_mm3', 'exc_mm3', 'glia_mm3', 'astro_mm3', 'oligo_mm3', 'microglia_mm3', 'nonneuron_mm3']
# #etypes = fetypes.dropna(subset=columns_to_check, how='all')
# ttypes = fttypes.dropna(subset=columns_to_check, how='all')
#
# # Keep only the columns that are in columns_to_check, plus 'acronym' if you need it
# #etypes = etypes.loc[:, ['acronym'] + columns_to_check]  # Including 'acronym' for indexing or merging purposes
# ttypes = ttypes.loc[:, ['acronym'] + columns_to_check]  # Including 'acronym' for indexing or merging purposes

# %%
#Helper function to create total cell count values for a 3D brain

# import re
# import pandas as pd
# import numpy as np

def nrrd_for_validation(df, parcellation_annotation, CCFv3):
    all_ids_for_df = []
    df_comb = pd.DataFrame()

    for regionname in df.index.values[0:]:
        density = df.loc[regionname, 'density_mm3']
        #annotation_id_info = substructures[substructures['cluster_as_filename'] == regionname]
        annotation_id_info = parcellation_annotation[parcellation_annotation['cluster_as_filename'] == regionname]

        Annotation2020ids = [int(re.search(r'\d+$', s).group()) for s in annotation_id_info['parcellation_label'].values]
        df_sub = pd.DataFrame({'density': density}, index=Annotation2020ids)
        df_comb = pd.concat([df_comb, df_sub])
        all_ids_for_df.append(Annotation2020ids)

    all_ids_for_df = [value for sublist in all_ids_for_df for value in sublist]
    all_ids_for_df.append(0)
    #Place to put extra regions not part of Allen's Parcellation annotation

    outside = 0
    outsideid = [0]
    df_sub = pd.DataFrame({'density': outside}, index=outsideid)
    df_comb = pd.concat([df_comb, df_sub])

    CCFv3_copy = CCFv3.copy()

    # Expression is 0 in those regions where we don't have any info:
    CCFv3_copy[~np.isin(CCFv3_copy, all_ids_for_df)] = 0.0 

    # Expression is non-zero in these leaf region(s)
    for index, row in df_comb.iterrows():
        density_value = row['density']
        region_id = index
        CCFv3_copy[np.isin(CCFv3, region_id)] = density_value

    #Create outside of the brain as 0
    CCFv3_copy[np.isin(CCFv3, int(0))] = 0

    return CCFv3_copy

# %%
# %%time

import re

data_folder = "/gpfs/bbp.cscs.ch/project/proj84/piluso/share/general/warped_augmented_CCFv3/"
CCFv3, _ = nrrd.read(f'{data_folder}annotation_25_2022_CCFv3a.nrrd')


#from multiprocessing import Pool

def process_type(types, file_name):
    # Filter DataFrames based on types
    filtered_dataframes = {key: value for key, value in shuffled_combined_dataframes.items() if key in types}
    
    # Combine filtered DataFrames
    combined_df = pd.concat(filtered_dataframes.values())
    
    # Sum the combined DataFrame by index
    summed_df = combined_df.groupby(combined_df.index).sum()
    
    # Validate result
    result = nrrd_for_validation(summed_df, parcellation_annotation, CCFv3)
    
    # Clean up
    del combined_df, summed_df, filtered_dataframes

    return (result, file_name)

def main():
    # Define the parameters for each process
    tasks = [
        (neurontypes, "scaled_total_neuron_densities"),
        (exctypes, "scaled_total_excitatory_densities"),
        (inhtypes, "scaled_total_inhibitory_densities"),
        (astrotypes, "scaled_total_astrotypes_densities"),
        (microglia, "scaled_total_microglia_densities"),
        (oligos, "scaled_total_oligocyte_densities"),
        (glia, "scaled_total_glia_densities"),
        (exci_inhib_sum, "scaled_total_excinh_densities"),
        (celltypes, "scaled_total_celltypes_densities"),
        (nonneurontypes, "scaled_total_nonneuron_densities")
    ]
    
    # Create a multiprocessing Pool
    with mp.Pool(processes=mp.cpu_count()) as pool:
        results = pool.starmap(process_type, tasks)
    
    # Sequentially write the .nrrd files to avoid concurrent writes
    for result, file_name in results:
        nrrd.write(f"{root_folder}total_nrrd_global_only/{file_name}.nrrd", result)
        print(f"{root_folder}total_nrrd/{file_name}.nrrd")
        
if __name__ == "__main__":
    main()

# %% [markdown]
# # PART 2 - Transplant (if needed)

# %% [markdown]
# In this section we specifically edit a few regions based on inputs from other colleagues / literature values
#
# - First, we create a dataframe with the expected density values.
# - Second, we compare this ground truth (or expected values) with the densities originating from transcriptomic data and calculate their ratio: exc_mm3_ratio	inh_mm3_ratio	neurons_mm3_ratio (for this we can use the total densities nrrd files for simplicity)
# - Third, we adjust the transcriptomic densities (by multiplying with the ratio) in the generated pickle file.
#
# This way any future input can be added to the original df: df_expected, a ratio can be calculated, and transcriptomic densities can be updated.
# Important to note that pickle files are derived values from csv files (and mean that the values have been collected and updated). nrrd files are derived from these pickle files as per our logic, and they only serve as "projections" of the actual data.

# %%
# Create a dictionary from the expected data:
data = {
    "id": [391, 399, 407, 415, 431, 438, 446, 454, 471, 486, 495, 504, 718, 733, 1020],
    "acronym": [
        "CA1slm", "CA1so", "CA1sp", "CA1sr", "CA2slm", "CA2so", 
        "CA2sp", "CA2sr", "CA3slm", "CA3so", "CA3sp", "CA3sr", "VPL", "VPM", "PO"
    ],
    "Region": [
        "Field CA1, stratum lacunosum-moleculare", "Field CA1, stratum oriens",
        "Field CA1, stratum pyramidale", "Field CA1, stratum radiatum",
        "Field CA2, stratum lacunosum-moleculare", "Field CA2, stratum oriens",
        "Field CA2, stratum pyramidale", "Field CA2, stratum radiatum",
        "Field CA3, stratum lacunosum-moleculare", "Field CA3, stratum oriens",
        "Field CA3, stratum pyramidale", "Field CA3, stratum radiatum",
        "Ventral posterolateral nucleus of the thalamus", "Ventral posteromedial nucleus of the thalamus",
        "Posterior complex of the thalamus"
    ],
    "Expected Inhibitory Dorsal": [
        8420, 6480, 13520, 6480, 8420, 6480, 13520, 3240, 5780, 3170, 7560, 7890, "", "", ""
    ],
    "Expected Inhibitory Ventral": [
        8820, 10500, 10130, 10500, 8820, 10500, 10130, 4260, 7200, 5460, 10540, 6590, "", "", ""
    ],
    "Expected Neurons Dorsal": [
        "", "", 447500, "", "", "", 447500, "", "", "", "", "", "", "", ""
    ],
    "Expected Neurons Ventral": [
        "", "", 180500, "", "", "", 180500, "", "", "", "", "", "", "", ""
    ],
    "exc_mm3": [
        "", "", "", "", "", "", "", "", "", "", "", "", 55340.64, 67940.58, ""
    ],
    "inh_mm3": [
        8620, 8490, 11825, 8490, 8620, 8490, 11825, 3750, 6490, 4315, 9050, 7240, 2126.28, 2978.61, 161.08663
    ],
    "neurons_mm3": [
        "", "", 314000, "", "", "", 314000, "", "", "", 172400, "", 57466.92, 70919.19, ""
    ]
}

# Create a DataFrame from the dictionary
df_e = pd.DataFrame(data)


# New data to be added
new_data = {
    "id": [212, 220, 228, 236, 244, 477],
    "acronym": [
        "MOBglomerularlayer", "MOBgr", "MOBipl", "MOBmi", "MOBopl", "STR"
    ],
    "Region": [
        "Main olfactory bulb, glomerular layer", "Main olfactory bulb, granule layer",
        "Main olfactory bulb, inner plexiform layer", "Main olfactory bulb, mitral layer",
        "Main olfactory bulb, outer plexiform layer", "Striatum"
    ],
    "Expected Inhibitory Dorsal": ["", "", "", "", "", ""],
    "Expected Inhibitory Ventral": ["", "", "", "", "", ""],
    "Expected Neurons Dorsal": ["", "", "", "", "", ""],
    "Expected Neurons Ventral": ["", "", "", "", "", ""],
    "exc_mm3": ["", "", "", "", "", ""],
    "inh_mm3": ["", "", "", "", "", ""],
    "neurons_mm3": [
        630000, 710000, 150000, 350000, 80000, 78560
    ]
}
df_new = pd.DataFrame(new_data)

# Concatenate the new data with the existing data
df_expected = pd.concat([df_e, df_new], ignore_index=True)
df_expected.to_csv('/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/expected_data.csv', index=False)

#Add children to the regions which need to change to include non-leaf-region changes:
file = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/df_hierarchy_ccfv3_l23split_barrelsplit.csv'
hierarchy = pd.read_csv(file, index_col=0)

# Merge df_expected with hierarchy on 'id' to get the 'children' column
df_expected = df_expected.merge(hierarchy[['id', 'children', 'acr_list']], on='id', how='left')

import ast
df_expected.loc[: , 'children'] = df_expected.loc[: , 'children'].apply(ast.literal_eval)

# Add new columns to df_expected
df_expected['exc_mm3_ratio'] = np.nan
df_expected['inh_mm3_ratio'] = np.nan
df_expected['neurons_mm3_ratio'] = np.nan

# %%
#These are the affacted regions
df_expected['acronym'].values
# Out:
# array(['CA1slm', 'CA1so', 'CA1sp', 'CA1sr', 'CA2slm', 'CA2so', 'CA2sp',
#        'CA2sr', 'CA3slm', 'CA3so', 'CA3sp', 'CA3sr', 'VPL', 'VPM', 'PO',
#        'MOBglomerularlayer', 'MOBgr', 'MOBipl', 'MOBmi', 'MOBopl', 'STR'],
#       dtype=object)

# %%
#Add scaling parameter to df_expected too by loading scaled total density files and search for corresponding values

data_folder = "/gpfs/bbp.cscs.ch/project/proj84/piluso/share/general/warped_augmented_CCFv3/"
CCFv3a, _ = nrrd.read(f'{data_folder}annotation_25_2022_CCFv3a.nrrd')
# CCFv3a, _ = nrrd.read("/gpfs/bbp.cscs.ch/data/project/proj84/atlas_pipeline_runs/2024-05-15T22:44:26+02:00/annotation_ccfv3_l23split_barrelsplit_validated.nrrd")

results_folder = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/'

#NEURON
filename = "scaled_total_neuron_densities.nrrd"
full_path = os.path.join(results_folder, filename)
if os.path.isfile(full_path):
    neuron, _ = nrrd.read(full_path)

#EXC
filename = "scaled_total_excitatory_densities.nrrd"
full_path = os.path.join(results_folder, filename)
if os.path.isfile(full_path):
    exc, _ = nrrd.read(full_path)
#INH        
filename = "scaled_total_inhibitory_densities.nrrd"
full_path = os.path.join(results_folder, filename)
if os.path.isfile(full_path):
    inh, _ = nrrd.read(full_path)

# %% [markdown]
# The next step calculates the ratio between expected and transcriptomic densities. It updates the df.

# %%
# %%time 

'''We divide by: mean expected / transcriptomic mean densities..'''

# Arrays to process
arrays = {
    'neurons_mm3': neuron,
    'inh_mm3': inh,
    'exc_mm3': exc,
}

# Worker function to process each row
def process_row(row):
    id_ = row['id'] 
    acr = row['acronym']
    name = row['Region']
    ids = row['children']
    ids.append(id_) #Make sure you add the original id_ to the children
    
    
    # Create a mask for the current id list
    mask = np.isin(CCFv3a, [ids])
    
    # Calculate mean/median values (can place NaN or None in the regions not present in CCfV3a)
    # mean_values = {name: arr[mask].mean() if arr[mask].size > 
    #                0 else np.nan for name, arr in arrays.items()}
    mean_values = {name: arr[mask].mean() if arr[mask].size > 
                   0 else None for name, arr in arrays.items()}
    # mean_values = {name: np.median(arr[mask]) if arr[mask].size > 
    #                0 else None for name, arr in arrays.items()}

    # Update row with ratio values
    if mean_values['exc_mm3'] is not np.nan and isinstance(row['exc_mm3'], (int, float)):
        row['exc_mm3_ratio'] = row['exc_mm3'] / mean_values['exc_mm3']
    if mean_values['inh_mm3'] is not np.nan and isinstance(row['inh_mm3'], (int, float)):
        row['inh_mm3_ratio'] = row['inh_mm3'] / mean_values['inh_mm3']
    if mean_values['neurons_mm3'] is not np.nan and isinstance(row['neurons_mm3'], (int, float)):
        row['neurons_mm3_ratio'] = row['neurons_mm3'] / mean_values['neurons_mm3']
    
    return row
    
    
# Use multiprocessing Pool to process rows in parallel
if __name__ == '__main__':
    with mp.Pool(processes=mp.cpu_count()) as pool:
        new_data = pool.map(process_row, [row for _, row in df_expected.iterrows()])
    
    # Convert the list of rows back to a DataFrame
    df_expected = pd.DataFrame(new_data)
# Out:
# CPU times: user 190 ms, sys: 780 ms, total: 970 ms
# Wall time: 5.2 s

# %%
#We can't use csv files with densities as those are not scaled, but we can use the scaled density pickle file
root_folder = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/'

file = os.path.join( root_folder, 'scaled_densities_global_only.pickle' )
#Load region id volumes from volume_calc_from_template.ipynb
with open(file, 'rb') as pickle_file:
    scaled_combined_result_dataframe_from_file = pickle.load(pickle_file)
print("Loaded pickle file.")
# Out:
# Loaded pickle file.

# %% [markdown]
# Prepare the scaling. We have to solve again the regional differences between the transcriptomic data and expected densities. We search for regions not present in the transcriptomically covered regions and break them up to their leaf regions. We store the final list of (leaf) regions in a concatenated list.

# %%
import ast 
#Note that we will scale the scaled data: scaled_combined_result_dataframes
combined_result_dataframes_copy = copy.deepcopy(scaled_combined_result_dataframe_from_file)


for reg in df_expected['acronym'].values:
    concatenated_result = np.array(df_expected['acronym'].values) 
    if reg not in list(combined_result_dataframes_copy.keys()):
        print(reg, " is not a region recognised by transcriptomics data")
        #leaves_list = df_expected[df_expected['acronym'] == reg]['children'].iat[0]
        acr_list_str = df_expected[df_expected['acronym'] == reg]['acr_list'].iat[0]
        acr_list = ast.literal_eval(acr_list_str)

        # Concatenate the array and the list to cover the full area where secondary scaling takes effect
        # We combine the leaf regions with the list of regions non leaf regions
        concatenated_result = np.concatenate((concatenated_result, acr_list))
        print(len(acr_list), len(df_expected['acronym'].values), len(concatenated_result))
# Out:
# STR  is not a region recognised by transcriptomics data
# 30 21 51

# %%
string_to_find = "AAA"
matches = df_expected.map(lambda x: string_to_find in str(x))
# Find rows where any cell contains the substring
rows_with_substring = df_expected[matches.any(axis=1)]

# %%
# %%time

#Load metadata of cell type information. Using classes we can easily group all 5k+ ctypes into larger groups
meta_path = "/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/metadata/WMB-10X/20231215/views/cell_metadata_with_cluster_annotation.csv"
columns_to_read = ['class', 'subclass', 'cluster']
#metadata = pd.read_csv(meta_path, dtype={'cell_label':str}, low_memory=False)
metadata = pd.read_csv(meta_path, usecols=columns_to_read, )

n_classes = ['01 IT-ET Glut', '02 NP-CT-L6b Glut', '03 OB-CR Glut',
       '04 DG-IMN Glut', '05 OB-IMN GABA', '06 CTX-CGE GABA',
       '07 CTX-MGE GABA', '08 CNU-MGE GABA', '09 CNU-LGE GABA',
       '10 LSX GABA', '11 CNU-HYa GABA', '12 HY GABA', '13 CNU-HYa Glut',
       '14 HY Glut', '15 HY Gnrh1 Glut', '16 HY MM Glut', '17 MH-LH Glut',
       '18 TH Glut', '19 MB Glut', '20 MB GABA', '21 MB Dopa',
       '22 MB-HB Sero', '23 P Glut', '24 MY Glut', '25 Pineal Glut',
       '26 P GABA', '27 MY GABA', '28 CB GABA', '29 CB Glut',]

nn_classes = ['30 Astro-Epen', '31 OPC-Oligo', '32 OEC', '33 Vascular',
       '34 Immune']

exc = ['01 IT-ET Glut', '02 NP-CT-L6b Glut', '03 OB-CR Glut',
      '04 DG-IMN Glut', '13 CNU-HYa Glut', '14 HY Glut', '15 HY Gnrh1 Glut', '16 HY MM Glut', '17 MH-LH Glut',
      '18 TH Glut', '19 MB Glut', '23 P Glut', '24 MY Glut', '25 Pineal Glut', '29 CB Glut',]
inh = ['05 OB-IMN GABA', '06 CTX-CGE GABA', '07 CTX-MGE GABA', '08 CNU-MGE GABA', '09 CNU-LGE GABA',
      '10 LSX GABA', '11 CNU-HYa GABA', '12 HY GABA', '20 MB GABA', '26 P GABA', '27 MY GABA', '28 CB GABA', ]
other = ['21 MB Dopa', '22 MB-HB Sero', ]
exci_inhib_su = exc + inh

astrotypes = ['5206 Bergmann NN_1', '5207 Astro-CB NN_1', '5208 Astro-NT NN_1',
       '5209 Astro-NT NN_1', '5210 Astro-NT NN_1', '5211 Astro-NT NN_1',
       '5212 Astro-NT NN_1', '5213 Astro-NT NN_1', '5214 Astro-NT NN_2',
       '5215 Astro-NT NN_2', '5216 Astro-NT NN_2', '5217 Astro-NT NN_2',
       '5218 Astro-TE NN_1', '5219 Astro-TE NN_1', '5220 Astro-TE NN_1',
       '5221 Astro-TE NN_1', '5222 Astro-TE NN_2', '5223 Astro-TE NN_2',
       '5224 Astro-TE NN_3', '5225 Astro-TE NN_3', '5226 Astro-TE NN_3',
       '5227 Astro-TE NN_3', '5228 Astro-TE NN_4', '5229 Astro-TE NN_5',
       '5230 Astro-TE NN_5', '5231 Astro-OLF NN_1', '5232 Astro-OLF NN_1',
       '5233 Astro-OLF NN_2', '5234 Astro-OLF NN_2',
       '5235 Astro-OLF NN_3', '5236 Astro-OLF NN_3',]

microglia = ['5312 Microglia NN_1']

oligos = ['5266 OPC NN_1', '5267 OPC NN_1',
       '5268 OPC NN_1', '5269 OPC NN_1', '5270 OPC NN_1', '5271 OPC NN_2',
       '5272 COP NN_1', '5273 COP NN_1', '5274 COP NN_1', '5275 COP NN_1',
       '5276 COP NN_1', '5277 COP NN_1', '5278 NFOL NN_2',
       '5279 NFOL NN_2', '5280 NFOL NN_2', '5281 NFOL NN_2',
       '5282 MFOL NN_3', '5283 MFOL NN_3', '5284 MOL NN_4',
       '5285 MOL NN_4', '5286 MOL NN_4', '5287 MOL NN_4', '5288 MOL NN_4',]

glia = astrotypes + microglia + oligos

neurontypes = np.unique(metadata[metadata['class'].isin(n_classes)]['cluster'].values)
nonneurontypes = np.unique(metadata[metadata['class'].isin(nn_classes)]['cluster'].values)
exctypes = np.unique(metadata[metadata['class'].isin(exc)]['cluster'].values)
inhtypes = np.unique(metadata[metadata['class'].isin(inh)]['cluster'].values)
othertypes = np.unique(metadata[metadata['class'].isin(other)]['cluster'].values)
exci_inhib_sum = np.unique(metadata[metadata['class'].isin(exci_inhib_su)]['cluster'].values)
# Out:
# CPU times: user 13.6 s, sys: 401 ms, total: 14 s
# Wall time: 14 s

# %% [markdown]
# Do the scaling: we can scale according to input inhibitory / excitatory / neuron count/

# %%
# %%time

combined_result_dataframes_copy = copy.deepcopy(scaled_combined_result_dataframe_from_file)
# del scaled_combined_result_dataframes
# We create the dict of dfs anew!
scaled_combined_result_dataframes = {}

#Do the 2ndary scaling: we check every transcriptomic region and scale their cell types if needed: 
for key, df in combined_result_dataframes_copy.items():
    if key in concatenated_result:
        print(key, " is a leaf region which will be scaled.")
        # We find the row where this region is listed (can be a substring if the row is not a leaf region)
        matches = df_expected.map(lambda x: key in str(x))
        rows_with_substring = df_expected[matches.any(axis=1)]
        # If the region has a non-NAN value in the ratios, we multiply that type of cells with the ratio
        if not rows_with_substring.empty and pd.notna(rows_with_substring['exc_mm3_ratio'].iloc[0]):
            mask = df.index.isin(exctypes)
            df.loc[mask, 'density_mm3'] *= rows_with_substring['exc_mm3_ratio'].iloc[0]
            scaled_combined_result_dataframes[key] = df
        #break
        if not rows_with_substring.empty and pd.notna(rows_with_substring['inh_mm3_ratio'].iloc[0]):
            mask = df.index.isin(inhtypes)
            df.loc[mask, 'density_mm3'] *= rows_with_substring['inh_mm3_ratio'].iloc[0]
            scaled_combined_result_dataframes[key] = df

        if not rows_with_substring.empty and pd.notna(rows_with_substring['neurons_mm3_ratio'].iloc[0]):
            mask = df.index.isin(neurontypes)
            df.loc[mask, 'density_mm3'] *= rows_with_substring['neurons_mm3_ratio'].iloc[0]
            scaled_combined_result_dataframes[key] = df
            #break
        #print("Deleting data for " + key)
        del key, df        
    else:
       #In this case we don't have to scale
        scaled_combined_result_dataframes[key] = df
        del key, df
# Out:
# AAA  is a leaf region which will be scaled.
# ACB  is a leaf region which will be scaled.
# BA  is a leaf region which will be scaled.
# CA1slm  is a leaf region which will be scaled.
# CA1so  is a leaf region which will be scaled.
# CA1sp  is a leaf region which will be scaled.
# CA1sr  is a leaf region which will be scaled.
# CA2slm  is a leaf region which will be scaled.
# CA2so  is a leaf region which will be scaled.
# CA2sp  is a leaf region which will be scaled.
# CA2sr  is a leaf region which will be scaled.
# CA3slm  is a leaf region which will be scaled.
# CA3so  is a leaf region which will be scaled.
# CA3sp  is a leaf region which will be scaled.
# CA3sr  is a leaf region which will be scaled.
# CEAc  is a leaf region which will be scaled.
# CEAl  is a leaf region which will be scaled.
# CEAm  is a leaf region which will be scaled.
# CP  is a leaf region which will be scaled.
# FS  is a leaf region which will be scaled.
# IA  is a leaf region which will be scaled.
# LSc  is a leaf region which will be scaled.
# LSr  is a leaf region which will be scaled.
# LSv  is a leaf region which will be scaled.
# MOBglomerularlayer  is a leaf region which will be scaled.
# MOBgr  is a leaf region which will be scaled.
# MOBipl  is a leaf region which will be scaled.
# MOBmi  is a leaf region which will be scaled.
# MOBopl  is a leaf region which will be scaled.
# PO  is a leaf region which will be scaled.
# SF  is a leaf region which will be scaled.
# SH  is a leaf region which will be scaled.
# VPL  is a leaf region which will be scaled.
# VPM  is a leaf region which will be scaled.
# CPU times: user 127 ms, sys: 9.11 ms, total: 137 ms
# Wall time: 133 ms

# %%
len(scaled_combined_result_dataframes)
# Out:
# 703

# %%
folder = '/gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/'
# Assuming 'total_cells' is your dictionary of DataFrames
with open(f'{folder}scaled_densities_global_only_plus_transplant.pickle', 'wb') as f:
    pickle.dump(scaled_combined_result_dataframes, f)

print(f"Saved here: {folder}")
# Out:
# Saved here: /gpfs/bbp.cscs.ch/data/project/proj84/csaba/aibs_10x_mouse_wholebrain/results/density_calculations/
